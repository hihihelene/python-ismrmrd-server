# %% [markdown]
# # Create/convert an input dataset in MRD format
#
# Prepare a dataset in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html) by converting acquired data or by generating a synthetic phantom dataset.  Raw k-space data can be converted using tools such as [siemens_to_ismrmrd](https://github.com/ismrmrd/siemens_to_ismrmrd), [ge_to_ismrmrd](https://github.com/ismrmrd/ge_to_ismrmrd), [philips_to_ismrmrd](https://github.com/ismrmrd/philips_to_ismrmrd), and [bruker_to_ismrmrd](https://github.com/ismrmrd/bruker_to_ismrmrd), while DICOM image data can be converted to DICOM using [dicom2mrd.py](https://github.com/kspaceKelvin/python-ismrmrd-server#UsingDICOMimagesasinputdata).  The [generate_cartesian_shepp_logan_dataset.py](../generate_cartesian_shepp_logan_dataset.py) script can also be used to generate multi-channel raw k-space data.

# %% [markdown]
# ## Option 1: Simulate a raw k-space dataset of the Shepp-Logan phantom
# **Note** This section requires that the [ismrmrd-python-tools](https://github.com/ismrmrd/ismrmrd-python-tools) repo be installed (see [readme.md](../readme.md#Settingupacondaenvironment))

# %%
# Generate a raw k-space dataset of the Shepp-Logan phantom
import os
import generate_cartesian_shepp_logan_dataset

inputFilename = 'data/raw.mrd'

dir, file = os.path.split(inputFilename)
if dir and not os.path.exists(dir):
    print(f'Creating parent directory {dir}')
    os.makedirs(dir)

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

generate_cartesian_shepp_logan_dataset.create(filename=inputFilename, matrix_size=256, coils=8, oversampling=2, repetitions=1, acceleration=1, noise_level=0.05)
# Out:
# Creating Shepp-Logan phantom raw data:
# Matrix 256x256 at R=1 with 1 repetitions
# 8 coils with 2 oversampling and 0.05 noise level
# Saved to data/raw.mrd

# %% [markdown]
# ## Option 2: Convert raw k-space data acquired from an MRI scanner

# %%
# Run siemens_to_ismrmrd to convert a .dat file into MRD format
# Note that as there is no Windows executable, this must be run in Linux or in a devcontainer

# Relative path to Siemens .dat file (note this .ipynb file likely exists in the doc subfolder!)
datFile = 'data/MiniFLASH_Fire.dat'

# Measurement in the multi-RAID .dat file to convert.  Note the .dat file may contain dependent
# scans, e.g. AdjCoilSens and the desired scan is usually the last in the multi-RAID file
# Negative indices are relative to the end (e.g. -1 for the last measurement)
measNum = '-1'

# Parameter map and stylesheet to use to convert from Siemens parameter buffers to an MRD header.
# These can specify a relative path to local files or files embedded inside siemens_to_ismrmrd.
# These arguments can also be omitted and will default to these values.
paramMap      = None
paramMapStyle = None

# The output file can be specified with the "--output" option, but will be named with the same
# filename as the input file (with a .mrd extension) if omitted.

import subprocess
import os

inputFilename = os.path.splitext(datFile)[0] + '.mrd'
if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

command = ['siemens_to_ismrmrd', '--measNum', measNum, '--file', datFile]
if paramMap is not None:
    command.extend(('--pMap', paramMap))

if paramMapStyle is not None:
    command.extend(('--pMapStyle', paramMapStyle))

try:
    result = subprocess.run(command, check=True, text=True, capture_output=True)
    print("Output:", result.stdout)
except subprocess.CalledProcessError as e:
    raise Exception("Error:", e.stderr)
# Out:
# Output: Siemens file is: data/MiniFLASH_Fire.dat
# Output file not specified -- using data/MiniFLASH_Fire.mrd
# -----------------------------------------------------------------
# Converting measurement 1 into file data/MiniFLASH_Fire.mrd in group dataset
# -----------------------------------------------------------------
# Using parameter map: IsmrmrdParameterMap_Siemens.xml
# This file contains 1 measurement(s).
# VD line file detected.
# Protocol name [1]: MiniFLASH_Fire
# Number of parameter buffers: 6
# Buffer Name: Config
# Buffer Name: Dicom
# Buffer Name: Meas
# Buffer Name: MeasYaps
# Buffer Name: Phoenix
# Buffer Name: Spice
# Trajectory is: 1
# Failed to find YAPS.lFirstFourierLine array
# Failed to find YAPS.lFirstFourierPartition array
# center_line = 64
# center_partition = 0
# Baseline: N4_VE11C_LATEST_20160120
# Software version: syngo MR E11
# Protocol name: MiniFLASH_Fire
# Dwell time: 15000
# Using parameter XSL: IsmrmrdParameterMap_Siemens.xsl
# Study time: 16:06:09
# Last scan reached...

# %% [markdown]
# ## Visualize raw k-space data
# Inspect and visualize the raw k-space dataset using the [ismrmrd-python](https://github.com/ismrmrd/ismrmrd-python) library.  Data from multiple scans/acquisitions can be stored in a single file, grouped in ['datasets'](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html#mrd-file-format).  The datasets in a file can be listed with:

# %%
# Display the generated raw k-space data
import h5py
import ismrmrd
import numpy as np
import matplotlib.pyplot as plt

datasetName = 'dataset'

# List all datasets in the file
with h5py.File(inputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File "%s" contains %d datasets:' % (inputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[0]

    datasetName = list(d.keys())[0]

print('Reading dataset "%s" from file "%s"' % (datasetName, inputFilename))
with ismrmrd.Dataset(inputFilename, datasetName, False) as dset:
    # Read MRD header
    xmlHeader = dset.read_xml_header().decode('utf-8')
    mrdHeader = ismrmrd.xsd.CreateFromDocument(xmlHeader)

    # Get all readouts
    acqs = [dset.read_acquisition(idx) for idx in range(dset.number_of_acquisitions())]

    # Limit to imaging (non-noise) readouts
    imgAcqs = [acq for acq in acqs if not acq.is_flag_set(ismrmrd.ACQ_IS_NOISE_MEASUREMENT)]

    print('There are %d imaging readouts out of a total of %d readouts' % (len(imgAcqs), dset.number_of_acquisitions()))

# List index counters that have >1 unique values
idxFields = ['average', 'contrast', 'kspace_encode_step_1', 'kspace_encode_step_2', 'phase', 'repetition', 'segment', 'set', 'slice']
print("Loop index counters with unique values:")
for field in idxFields:
    vals = set([getattr(acq.idx, field) for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  {field:20s} has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

for i in range(8):
    vals = set([acq.idx.user[i] for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  user[{i}]              has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

# Format data into single [cha PE RO rep] array
lin = [acq.idx.kspace_encode_step_1 for acq in imgAcqs]
rep = [acq.idx.repetition           for acq in imgAcqs]

raw = np.zeros((mrdHeader.acquisitionSystemInformation.receiverChannels, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.y, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.x, 
                mrdHeader.encoding[0].encodingLimits.repetition.maximum+1), 
                imgAcqs[0].data.dtype)

for acq, lin, rep in zip(imgAcqs, lin, rep):
    raw[:,lin,-acq.data.shape[1]:,rep] = acq.data

# Show the AcquisitionHeader flags for each line of k-space
print("Readouts with AcquisitionHeader flags present:")
acqFlags = [field for field in dir(ismrmrd) if field.startswith('ACQ_')]
for i, acq in enumerate(imgAcqs):
    strFlags = ", ".join([field for field in acqFlags if acq.is_flag_set(getattr(ismrmrd, field))])
    if strFlags:
        print(f'[{i:3d}] Lin {acq.idx.kspace_encode_step_1}: {strFlags}')

t = np.log(np.abs(raw[0,:,:,0]))
t[np.isinf(t)] = 0

dpi = 100
plt.figure(figsize=(3*t.shape[1] / dpi, 3*t.shape[0] / dpi), dpi=dpi)
plt.imshow(t, interpolation='nearest')
plt.title('Raw k-space (rep %d/%d, coil %d/%d)' % (1, mrdHeader.encoding[0].encodingLimits.repetition.maximum+1, 1, mrdHeader.acquisitionSystemInformation.receiverChannels))
# plt.axis('off')
plt.show()
# Out:
# File "data/MiniFLASH_Fire.mrd" contains 1 datasets:
#   dataset
# Reading dataset "dataset" from file "data/MiniFLASH_Fire.mrd"
# There are 128 imaging readouts out of a total of 128 readouts
# Loop index counters with unique values:
#   kspace_encode_step_1 has 128 unique values (min:   0, max: 127)
# Readouts with AcquisitionHeader flags present:
# [  0] Lin 0: ACQ_FIRST_IN_SLICE
# [127] Lin 127: ACQ_LAST_IN_MEASUREMENT, ACQ_LAST_IN_REPETITION, ACQ_LAST_IN_SLICE

# %% [markdown]
# ## Option 3: Convert a set of DICOMs
# For image processing workflows, it may also be useful to use DICOM images as input data.  These can be converted to MRD format using the [dicom2mrd.py](../dicom2mrd.py) script.  Not that the header information from data converted in this way may differ from data converted from the scanner.

# %%
# Folder containing DICOM files
import os
dicomFolder   = r'C:\Lung_Project\Measurements\CDH_Study\20251018_age10'
inputFilename = 'data/dicoms.mrd'

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

import dicom2mrd
from types import SimpleNamespace

# Adjust the logging configuration otherwise INFO level isn't shown in notebook output
import logging
logging.getLogger().setLevel(logging.INFO)

# Specify client arguments for recon
args = SimpleNamespace(**dicom2mrd.defaults)
args.folder   = dicomFolder
args.outFile  = inputFilename

dicom2mrd.main(args)
# Out:
# Found 1 unique series from 280 files in folder C:\Lung_Project\Measurements\CDH_Study\20251018_age10
# Creating MRD XML header from file C:\Lung_Project\Measurements\CDH_Study\20251018_age10\1.dcm
# <?xml version="1.0" encoding="ascii"?>
# <ismrmrdHeader xmlns="http://www.ismrm.org/ISMRMRD">
#  <studyInformation>
#   <studyDate>2025-10-28</studyDate>
#   <studyTime>09:47:16</studyTime>
#   <studyID>04879831</studyID>
#   <studyDescription>Kinderprotokolle Untersuchung_neu</studyDescription>
#   <studyInstanceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000297</studyInstanceUID>
#   <bodyPartExamined>LUNG</bodyPartExamined>
#  </studyInformation>
#  <measurementInformation>
#   <measurementID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000305</measurementID>
#   <patientPosition>HFS</patientPosition>
#   <protocolName>trufi_lung</protocolName>
#   <frameOfReferenceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000306</frameOfReferenceUID>
#  </measurementInformation>
#  <acquisitionSystemInformation>
#   <systemVendor>Siemens Healthineers</systemVendor>
#   <systemModel>MAGNETOM Aera</systemModel>
#   <systemFieldStrength_T>1.5</systemFieldStrength_T>
#  </acquisitionSystemInformation>
#  <experimentalConditions>
#   <H1resonanceFrequency_Hz>63870000</H1resonanceFrequency_Hz>
#  </experimentalConditions>
#  <encoding>
#   <encodedSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </encodedSpace>
#   <reconSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </reconSpace>
#   <encodingLimits/>
#   <trajectory>cartesian</trajectory>
#   <parallelImaging>
#    <accelerationFactor>
#     <kspace_encoding_step_1>3</kspace_encoding_step_1>
#     <kspace_encoding_step_2>1</kspace_encoding_step_2>
#    </accelerationFactor>
#   </parallelImaging>
#  </encoding>
#  <sequenceParameters>
#   <TR>2.06</TR>
#   <flipAngle_deg>30.0</flipAngle_deg>
#  </sequenceParameters>
#  <userParameters>
#   <userParameterDouble>
#    <name>ReadoutOS</name>
#    <value>2.0</value>
#   </userParameterDouble>
#  </userParameters>
# </ismrmrdHeader>
#
# Series 19 has 280 images with 1 slices and 1 phases
# Creating MRD file data/dicoms.mrd with group dataset

# %% [markdown]
# ## Option 4: Save data using server.py
# For inline integration with an MRI scanner or another data source, the conversion to MRD may be done with vendor-provided software.  In this case, it may be desirable to use MRD server in this repository to save a copy of data that it receives, particularly for development purposes.  The data can then be re-run with [client.py](../client.py).  This can be achieved by starting the server with [main.py](../main.py) with the `-s` (`--savedata`) option and data is stored in `/tmp/share/saved_data` unless overridden by the `-S` (`--savedataFolder`) option.

# %%
inputFilename = 'data/dicoms.mrd'

# %% [markdown]
# # Run reconstruction
# Algorithms/reconstructions are run as modules by the server component, which implements the [MRD streaming protocol](https://ismrmrd.readthedocs.io/en/latest/mrd_streaming_protocol.html).  The server must be started separately and a client sends data to the server for processing.  The server can be started via command line by running `python main.py`.
#
# If using Visual Studio Code, [launch.json](../.vscode/launch.json) includes a debug configuration to run the server and allow for interactive debugging.  Click on the "Run and Debug" tab on the top left, then click the green play button to start the desired config ("Start server"):
#
# ![image-2.png](attachment:image-2.png)
#
# Breakpoints can be set by clicking to the left of the line number in a Python file:
#
# ![image.png](attachment:image.png)
#
# After the server is started, begin the reconstruction by running [client.py](../client.py) on the input dataset.  The recon code/module is selected by using the `config` argument.  The output is stored in a separate MRD file under a dataset named with the current date/time.

# %%
# Import the MRD client to send data to server for reconstruction
import client
from types import SimpleNamespace

# Adjust the logging configuration, otherwise INFO level isn't shown in notebook output by default
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

import datetime
outputFilename = 'data/recon.mrd'

# Specify client arguments for recon
args = SimpleNamespace(**client.defaults)
args.config    = 'custom.MAIN_VQMap'  # Recon module to be used
args.port      = 9020
args.out_group = str(datetime.datetime.now())  # Set when using in notebook, otherwise out_group is time of first import of client module
args.outfile   = outputFilename
args.filename  = inputFilename

client.main(args)
# Out:
# 2026-07-07 11:00:46,120 - Found additional config file custom.MAIN_VQMap.json
# 2026-07-07 11:00:46,126 - File data/dicoms.mrd contains 1 groups:
# 2026-07-07 11:00:46,127 - dataset
# 2026-07-07 11:00:46,128 - Reading data from group 'dataset' in file 'data/dicoms.mrd'
# 2026-07-07 11:00:46,130 - Connecting to MRD server at localhost:9020
# No logfile provided
# 2026-07-07 11:00:46,133 - Sending remote config file name 'custom.MAIN_VQMap'
# 2026-07-07 11:00:46,136 - --> Sending MRD_MESSAGE_CONFIG_FILE (1)
# 2026-07-07 11:00:46,145 - --> Sending MRD_MESSAGE_METADATA_XML_TEXT (3)
# 2026-07-07 11:00:46,146 - Sending configAdditional found in file custom.MAIN_VQMap.json:
# {
#     "version": "1.1.0",
#     "parameters": {
#         "options": "RGB",
#         "sendOriginal": "True",
#         "segmentationmethod": "automatic",
#         "spectralanalysis": "FD",
#         "phantom": true,
#         "skipfirst": 8
#     }
# }
# 2026-07-07 11:00:46,147 - --> Sending MRD_MESSAGE_TEXT (5)
# 2026-07-07 11:00:46,147 -     {
#     "version": "1.1.0",
#     "parameters": {
#         "options": "RGB",
#         "sendOriginal": "True",
#         "segmentationmethod": "automatic",
#         "spectralanalysis": "FD",
#         "phantom": true,
#         "skipfirst": 8
#     }
# }
# 2026-07-07 11:00:46,148 - Starting image data session
# 2026-07-07 11:00:46,149 - Reading images from '/dataset/image_0'
# 2026-07-07 11:00:46,164 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,172 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,181 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,188 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,197 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,204 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,211 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,620 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,627 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,633 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,639 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,645 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,652 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,657 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,663 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,668 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,674 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,680 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,686 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,692 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,698 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,702 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,709 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,714 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,719 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,725 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,730 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,735 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,742 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,747 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,752 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,758 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,764 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,769 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,778 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,784 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,789 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,794 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,800 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,805 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,811 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,816 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,822 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,828 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,833 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,838 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,844 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,849 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,854 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,861 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,866 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,871 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,877 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,883 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,888 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,894 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,899 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,904 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,911 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,916 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,921 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,927 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,932 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,937 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,943 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,948 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,953 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,959 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,965 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,969 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,976 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,981 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,986 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,992 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:46,998 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,003 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,009 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,014 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,020 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,025 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,031 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,036 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,042 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,047 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,053 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,059 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,065 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,070 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,076 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,081 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,086 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,093 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,098 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,104 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,110 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,116 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,121 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,127 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,135 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,141 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,148 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,154 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,160 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,166 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,171 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,177 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,183 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,189 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,204 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,216 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,223 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,233 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,242 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,249 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,257 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,264 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,271 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,279 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,285 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,296 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,304 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,313 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,319 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,326 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,333 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,340 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,347 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,353 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,362 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,368 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,376 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,383 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,389 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,395 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,401 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,407 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,413 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,419 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,425 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,431 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,436 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,443 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,449 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,454 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,460 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,465 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,471 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,478 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,484 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,490 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,496 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,502 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,508 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,513 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,519 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,525 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,531 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,536 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,543 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,549 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,554 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,561 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,566 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,572 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,578 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,584 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,589 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,595 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,601 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,607 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,612 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,618 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,625 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,630 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,635 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,642 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,648 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,652 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,659 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,664 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,669 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,676 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,681 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,686 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,693 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,698 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,704 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,710 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,716 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,721 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,728 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,732 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,738 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,745 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,750 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,756 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,761 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,767 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,772 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,778 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,784 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,789 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,795 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,800 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,805 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,812 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,817 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,822 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,827 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,832 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,837 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,843 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,848 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,854 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,860 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,866 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,871 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,878 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,883 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,888 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,894 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,900 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,906 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,912 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,917 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,924 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,929 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,935 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,940 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,949 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,955 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,961 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,967 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,973 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,979 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,985 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,991 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:47,997 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,003 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,009 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,014 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,020 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,026 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,032 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,037 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,044 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,050 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,056 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,062 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,068 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,074 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,080 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,085 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,091 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,097 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,103 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,109 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,115 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,120 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,126 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,132 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,138 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,144 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,150 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,155 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,161 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,166 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,172 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,178 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,184 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,189 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,196 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,201 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,207 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,212 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,218 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,224 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,230 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,236 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,244 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 11:00:48,247 - --> Sending MRD_MESSAGE_CLOSE (4)
# 2026-07-07 11:01:39,217 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,220 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,221 - Incoming data will be saved to: 'data/recon.mrd' in group '2026-07-07 11:00:46.119092'
# 2026-07-07 11:01:39,238 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,239 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,249 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,250 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,260 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,261 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,270 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,272 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,281 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,283 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,291 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,293 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,302 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,304 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,312 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,314 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,323 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,324 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,346 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,347 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,355 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,356 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,366 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,367 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,375 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,376 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,392 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,393 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,403 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,405 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,413 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,415 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,424 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,425 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,438 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,439 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,462 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,464 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,472 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,473 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,482 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,484 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,491 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,493 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,501 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,502 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,510 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,511 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,519 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,521 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,528 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,529 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,537 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,539 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,558 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,559 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,567 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,568 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,576 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,578 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,585 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,586 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,593 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,595 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,602 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,603 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,620 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,622 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,630 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,631 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,640 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,641 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,660 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,662 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,669 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,670 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,678 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,679 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,686 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,687 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,695 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,697 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,703 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,704 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,713 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,714 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,721 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,722 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,731 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,732 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,751 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,752 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,762 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,763 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,773 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,774 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,784 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,785 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,794 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,796 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,804 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,806 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,814 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,815 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,826 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,828 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,837 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,838 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,861 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,862 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,870 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,871 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,879 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,880 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,888 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,889 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,897 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,898 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,905 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,906 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,915 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,916 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,923 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,924 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,931 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,932 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,951 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,952 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,959 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,961 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,968 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,969 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,976 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,977 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,984 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,986 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:39,996 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:39,997 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,008 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,009 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,020 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,021 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,032 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,034 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,067 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,068 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,078 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,079 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,088 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,090 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,098 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,099 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,107 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,109 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,116 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,117 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,125 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,126 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,133 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,134 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,143 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,144 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,163 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,164 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,171 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,172 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,179 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,181 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,187 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,188 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,196 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,197 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,204 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,205 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,213 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,214 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,223 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,224 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,232 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,233 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,256 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,257 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,263 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,264 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,272 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,273 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,279 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,280 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,287 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,289 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,295 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,296 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,304 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,305 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,311 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,312 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,319 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,320 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,337 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,338 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,345 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,346 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,353 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,354 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,361 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,362 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,369 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,370 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,376 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,377 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,384 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,385 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,392 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,393 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,400 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,402 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,419 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,420 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,427 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,428 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,435 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,436 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,443 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,444 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,451 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,452 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,459 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,460 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,468 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,469 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,475 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,476 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,485 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,487 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,511 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,512 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,521 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,522 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,531 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,532 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,540 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,542 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,550 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,551 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,558 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,559 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,566 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,567 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,574 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,575 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,583 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,584 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,601 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,602 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,609 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,610 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,617 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,618 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,625 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,626 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,633 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,634 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,641 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,643 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,650 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,651 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,658 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,659 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,666 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,667 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,685 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,686 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,693 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,694 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,701 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,702 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,708 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,710 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,717 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,718 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,725 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,726 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,733 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,734 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,741 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,742 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,750 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,751 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:40,769 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:40,770 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# ...
# 2026-07-07 11:01:41,260 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,261 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,269 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,270 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,279 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,280 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,307 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,309 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,316 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,317 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,331 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,332 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,344 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,346 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,355 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,357 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,368 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,370 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,381 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,382 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,392 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,394 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,403 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,404 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,429 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,430 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,438 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,440 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,448 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,450 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,458 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,459 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,467 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,469 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,478 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,479 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,486 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,487 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,495 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,496 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,505 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,506 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,532 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,533 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,540 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,542 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,551 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,553 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,563 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,564 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,574 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,575 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,584 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,585 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,596 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,597 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,607 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,609 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,618 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,619 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,643 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,645 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,653 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,654 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,662 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,663 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,671 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,672 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,681 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,682 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,690 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,692 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,701 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,702 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,714 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,716 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,727 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,729 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,753 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,755 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,764 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,766 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,775 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,777 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,786 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,787 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,797 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,799 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,809 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,810 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,819 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,820 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,828 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,830 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,837 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,839 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,861 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,862 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,870 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,871 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,881 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,883 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,892 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,894 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,904 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,905 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,916 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,917 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,927 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,928 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,939 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,940 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,952 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,954 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,982 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,984 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:41,992 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:41,994 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,003 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,004 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,014 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,016 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,025 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,027 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,036 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,037 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,050 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,051 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,062 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,064 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,074 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,076 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,101 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,102 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,112 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,113 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,122 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,124 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,134 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,135 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,151 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,153 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,167 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,169 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,181 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,183 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,194 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,195 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,206 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,208 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,233 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,234 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,244 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,245 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,256 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,258 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,268 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,270 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,280 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,281 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,292 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,293 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,303 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,304 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,312 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,314 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,321 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,322 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,340 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,341 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,348 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,349 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,356 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,357 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,367 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,368 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,378 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,379 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,388 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,389 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,398 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,399 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,407 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,409 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,417 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,418 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,436 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-07-07 11:01:42,437 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-07-07 11:01:42,444 - <-- Received MRD_MESSAGE_CLOSE (4)
# 2026-07-07 11:01:42,445 -     Total received acquisitions:     0
# 2026-07-07 11:01:42,445 -     Total received images:         281
# 2026-07-07 11:01:42,446 -     Total received waveforms:        0
# 2026-07-07 11:01:42,447 - ------------------------------------------
# 2026-07-07 11:01:42,454 - Socket closed (writer)
# 2026-07-07 11:01:42,462 - ---------------------- Summary ----------------------
# 2026-07-07 11:01:42,463 - Sent     0 acquisitions  |  Received     0 acquisitions
# 2026-07-07 11:01:42,463 - Sent   280 images        |  Received   281 images
# 2026-07-07 11:01:42,463 - Sent     0 waveforms     |  Received     0 waveforms
# 2026-07-07 11:01:42,464 - Results written to data/recon.mrd
# 2026-07-07 11:01:42,464 - Session complete

# %% [markdown]
# # Display the reconstructed/processed images
# The output is an [HDF5-formatted file](https://www.hdfgroup.org/downloads/hdfview/) that is organized in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html).  It can be opened using MRD toolboxes for [python](https://github.com/ismrmrd/ismrmrd-python) or [MATLAB](https://github.com/ismrmrd/ismrmrd/tree/master/matlab/%2Bismrmrd) or the [ismrmrdviewer](https://github.com/ismrmrd/ismrmrdviewer).  The client can be run multiple times with the same output file and results are grouped by dataset.

# %%
# Display the reconstructed images
import h5py
import ismrmrd
import mrdhelper
import numpy as np
import matplotlib.pyplot as plt
import re

# Uncomment to display images from a different output file
outputFilename = 'data/recon.mrd'

# If run multiple times, the recon.mrd file will have multiple reconstructed images
# Find the most recent recon run
with h5py.File(outputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File %s contains %d groups (reconstruction runs):' % (outputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[-1]

with ismrmrd.Dataset(outputFilename, group, False) as dset:
    subgroups = dset.list()

    # Images are organized by series number in subgroups that start with 'image_' or 'images_'
    imgGroups = [group for group in list(subgroups) if (group.find('image_') != -1) or (group.find('images_') != -1)]
    imgGroupsWithNumImages = [f'{group} ({dset.number_of_images(group)} image{"s"[:dset.number_of_images(group)^1]})' for group in imgGroups]
    print('Group %s contains %d image series:' % (group, len(imgGroups)))
    print(' ', '\n  '.join(imgGroupsWithNumImages))

    # Show images
    fig, axs = plt.subplots(nrows=1, ncols=len(imgGroups), squeeze=False, figsize=(10,5))

    for i, series in enumerate(imgGroups):
        n = dset.number_of_images(series)
        img = dset.read_image(series, 0)
        meta = ismrmrd.Meta.deserialize(img.attribute_string)

        seriesNumber = re.search(r'(?<=_)\d+$', series).group(0)
        title = f'Series {re.search(r'(?<=_)\d+$', series).group(0)}, Image 1/{n}'
        if 'ImageComments' in meta.keys():
            title += '\n' + meta['ImageComments']

        axs[0][i].imshow(np.squeeze(img.data), cmap='gray')
        axs[0][i].set_title(title)
        axs[0][i].axis('off')
        axs[0][i].set_aspect('equal')

        # Read and plot ROIs
        for key in meta.keys():
            if not key.startswith('ROI_'):
                continue

            roi = meta[key]
            x, y, rgb, thickness, style, visibility = mrdhelper.parse_roi(roi)

            if visibility == 0:
                continue

            lstyle = '-' if (style == 0) else '--'
            axs[0][i].plot(x, y, color=rgb, linewidth=thickness, linestyle=lstyle)
        
        maxKeyLen = max([len(key) for key in meta.keys()])
        print("MetaAttributes:")
        for key, value in meta.items():
            print(f'  {key:{maxKeyLen}} : {value}')

    # Adjust layout to prevent clipping of titles
    plt.tight_layout(pad=0.5)

    plt.show()
# Out:
# File data/recon.mrd contains 82 groups (reconstruction runs):
#   2026-06-01 09:33:32.828918
#   2026-06-01 10:00:22.787041
#   2026-06-01 10:00:42.952301
#   2026-06-01 10:42:58.577762
#   2026-06-01 10:45:18.122040
#   2026-06-01 10:47:37.430498
#   2026-06-01 10:48:20.326888
#   2026-06-01 10:55:01.929994
#   2026-06-01 10:55:23.106971
#   2026-06-01 11:01:59.343331
#   2026-06-01 11:02:22.481313
#   2026-06-01 11:08:12.967541
#   2026-06-03 08:47:51.276796
#   2026-06-10 12:04:34.153889
#   2026-06-10 13:30:28.642786
#   2026-06-18 11:29:37.325057
#   2026-06-18 11:30:57.045951
#   2026-06-18 11:32:07.217002
#   2026-06-18 12:57:21.223093
#   2026-06-18 13:03:38.369658
#   2026-06-29 11:48:45.085287
#   2026-06-29 11:49:40.780163
#   2026-06-29 11:50:25.959546
#   2026-06-29 11:51:25.551268
#   2026-06-29 11:52:57.121881
#   2026-06-29 11:54:57.369100
#   2026-06-29 11:57:32.197499
#   2026-06-29 11:59:50.198185
#   2026-06-29 12:09:36.846528
#   2026-06-29 12:10:30.551481
#   2026-06-29 12:13:00.488793
#   2026-06-29 13:32:15.542261
#   2026-07-02 07:24:08.497167
#   2026-07-02 07:26:29.889842
#   2026-07-02 07:35:08.184958
#   2026-07-02 07:40:44.707861
#   2026-07-02 07:43:05.557287
#   2026-07-02 07:57:39.965291
#   2026-07-02 08:00:50.968532
#   2026-07-02 08:28:51.110756
#   2026-07-02 08:37:13.606138
#   2026-07-02 08:37:49.945050
#   2026-07-02 08:44:54.116342
#   2026-07-02 08:46:18.094615
#   2026-07-02 08:48:50.465965
#   2026-07-02 08:49:52.017281
#   2026-07-02 08:59:39.261517
#   2026-07-02 08:59:56.593309
#   2026-07-02 09:29:50.712332
#   2026-07-02 09:35:04.724098
#   2026-07-02 09:37:01.680073
#   2026-07-02 09:39:35.344017
#   2026-07-02 09:42:16.575656
#   2026-07-02 09:43:54.450253
#   2026-07-02 11:35:38.907687
#   2026-07-02 11:36:01.611713
#   2026-07-02 11:36:17.498831
#   2026-07-02 11:37:03.753683
#   2026-07-02 11:38:32.304329
#   2026-07-02 12:10:00.688646
#   2026-07-02 12:11:37.468003
#   2026-07-07 07:46:59.562875
#   2026-07-07 07:47:45.957575
#   2026-07-07 08:33:12.262893
#   2026-07-07 08:36:27.092851
#   2026-07-07 08:40:39.921038
#   2026-07-07 08:45:14.276525
#   2026-07-07 08:57:13.263730
#   2026-07-07 08:58:47.630691
#   2026-07-07 09:13:41.044813
#   2026-07-07 09:15:09.000479
#   2026-07-07 09:20:17.928610
#   2026-07-07 09:21:11.672038
#   2026-07-07 09:23:09.376111
#   2026-07-07 09:29:47.039537
#   2026-07-07 09:30:46.689168
#   2026-07-07 09:34:15.891772
#   2026-07-07 09:37:11.450032
#   2026-07-07 09:39:47.553578
#   2026-07-07 09:43:46.028412
#   2026-07-07 10:57:01.083366
#   2026-07-07 11:00:46.119092
# Group 2026-07-07 11:00:46.119092 contains 2 image series:
#   image_0 (1 image)
#   image_99 (280 images)
# MetaAttributes:
#   ImageType                     : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription           : trufi_lung
#   DicomJson                     : ...
#   DataRole                      : Image
#   ImageProcessingHistory        : ['PYTHON', 'INVERT']
#   WindowCenter                  : 2048.0
#   WindowWidth                   : 4096
#   SequenceDescriptionAdditional : FIRE
#   Keep_image_geometry           : 1
#   ImageRowDir                   : ['1.000000000000000000', '0.000000000000000000', '0.000000000000000000']
#   ImageColumnDir                : ['0.000000000000000000', '0.000000000000000000', '-1.000000000000000000']
# MetaAttributes:
#   ImageType           : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription : trufi_lung
#   DicomJson           : ...
#   Keep_image_geometry : 1
# /usr/local/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
