# %% [markdown]
# # Create/convert an input dataset in MRD format
#
# Prepare a dataset in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html) by converting acquired data or by generating a synthetic phantom dataset.  Raw k-space data can be converted using tools such as [siemens_to_ismrmrd](https://github.com/ismrmrd/siemens_to_ismrmrd), [ge_to_ismrmrd](https://github.com/ismrmrd/ge_to_ismrmrd), [philips_to_ismrmrd](https://github.com/ismrmrd/philips_to_ismrmrd), and [bruker_to_ismrmrd](https://github.com/ismrmrd/bruker_to_ismrmrd), while DICOM image data can be converted to DICOM using [dicom2mrd.py](https://github.com/kspaceKelvin/python-ismrmrd-server#UsingDICOMimagesasinputdata).  The [generate_cartesian_shepp_logan_dataset.py](../generate_cartesian_shepp_logan_dataset.py) script can also be used to generate multi-channel raw k-space data.

# %% [markdown]
# ## Option 1: Simulate a raw k-space dataset of the Shepp-Logan phantom
# **Note** This section requires that the [ismrmrd-python-tools](https://github.com/ismrmrd/ismrmrd-python-tools) repo be installed (see [readme.md](../readme.md#Settingupacondaenvironment))

# %%
# Generate a raw k-space dataset of the Shepp-Logan phantom
import os
import generate_cartesian_shepp_logan_dataset

inputFilename = 'data/raw.mrd'

dir, file = os.path.split(inputFilename)
if dir and not os.path.exists(dir):
    print(f'Creating parent directory {dir}')
    os.makedirs(dir)

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

generate_cartesian_shepp_logan_dataset.create(filename=inputFilename, matrix_size=256, coils=8, oversampling=2, repetitions=1, acceleration=1, noise_level=0.05)
# Out:
# Creating Shepp-Logan phantom raw data:
# Matrix 256x256 at R=1 with 1 repetitions
# 8 coils with 2 oversampling and 0.05 noise level
# Saved to data/raw.mrd

# %% [markdown]
# ## Option 2: Convert raw k-space data acquired from an MRI scanner

# %%
# Run siemens_to_ismrmrd to convert a .dat file into MRD format
# Note that as there is no Windows executable, this must be run in Linux or in a devcontainer

# Relative path to Siemens .dat file (note this .ipynb file likely exists in the doc subfolder!)
datFile = 'data/MiniFLASH_Fire.dat'

# Measurement in the multi-RAID .dat file to convert.  Note the .dat file may contain dependent
# scans, e.g. AdjCoilSens and the desired scan is usually the last in the multi-RAID file
# Negative indices are relative to the end (e.g. -1 for the last measurement)
measNum = '-1'

# Parameter map and stylesheet to use to convert from Siemens parameter buffers to an MRD header.
# These can specify a relative path to local files or files embedded inside siemens_to_ismrmrd.
# These arguments can also be omitted and will default to these values.
paramMap      = None
paramMapStyle = None

# The output file can be specified with the "--output" option, but will be named with the same
# filename as the input file (with a .mrd extension) if omitted.

import subprocess
import os

inputFilename = os.path.splitext(datFile)[0] + '.mrd'
if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

command = ['siemens_to_ismrmrd', '--measNum', measNum, '--file', datFile]
if paramMap is not None:
    command.extend(('--pMap', paramMap))

if paramMapStyle is not None:
    command.extend(('--pMapStyle', paramMapStyle))

try:
    result = subprocess.run(command, check=True, text=True, capture_output=True)
    print("Output:", result.stdout)
except subprocess.CalledProcessError as e:
    raise Exception("Error:", e.stderr)
# Out:
# Output: Siemens file is: data/MiniFLASH_Fire.dat
# Output file not specified -- using data/MiniFLASH_Fire.mrd
# -----------------------------------------------------------------
# Converting measurement 1 into file data/MiniFLASH_Fire.mrd in group dataset
# -----------------------------------------------------------------
# Using parameter map: IsmrmrdParameterMap_Siemens.xml
# This file contains 1 measurement(s).
# VD line file detected.
# Protocol name [1]: MiniFLASH_Fire
# Number of parameter buffers: 6
# Buffer Name: Config
# Buffer Name: Dicom
# Buffer Name: Meas
# Buffer Name: MeasYaps
# Buffer Name: Phoenix
# Buffer Name: Spice
# Trajectory is: 1
# Failed to find YAPS.lFirstFourierLine array
# Failed to find YAPS.lFirstFourierPartition array
# center_line = 64
# center_partition = 0
# Baseline: N4_VE11C_LATEST_20160120
# Software version: syngo MR E11
# Protocol name: MiniFLASH_Fire
# Dwell time: 15000
# Using parameter XSL: IsmrmrdParameterMap_Siemens.xsl
# Study time: 16:06:09
# Last scan reached...

# %% [markdown]
# ## Visualize raw k-space data
# Inspect and visualize the raw k-space dataset using the [ismrmrd-python](https://github.com/ismrmrd/ismrmrd-python) library.  Data from multiple scans/acquisitions can be stored in a single file, grouped in ['datasets'](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html#mrd-file-format).  The datasets in a file can be listed with:

# %%
# Display the generated raw k-space data
import h5py
import ismrmrd
import numpy as np
import matplotlib.pyplot as plt

datasetName = 'dataset'

# List all datasets in the file
with h5py.File(inputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File "%s" contains %d datasets:' % (inputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[0]

    datasetName = list(d.keys())[0]

print('Reading dataset "%s" from file "%s"' % (datasetName, inputFilename))
with ismrmrd.Dataset(inputFilename, datasetName, False) as dset:
    # Read MRD header
    xmlHeader = dset.read_xml_header().decode('utf-8')
    mrdHeader = ismrmrd.xsd.CreateFromDocument(xmlHeader)

    # Get all readouts
    acqs = [dset.read_acquisition(idx) for idx in range(dset.number_of_acquisitions())]

    # Limit to imaging (non-noise) readouts
    imgAcqs = [acq for acq in acqs if not acq.is_flag_set(ismrmrd.ACQ_IS_NOISE_MEASUREMENT)]

    print('There are %d imaging readouts out of a total of %d readouts' % (len(imgAcqs), dset.number_of_acquisitions()))

# List index counters that have >1 unique values
idxFields = ['average', 'contrast', 'kspace_encode_step_1', 'kspace_encode_step_2', 'phase', 'repetition', 'segment', 'set', 'slice']
print("Loop index counters with unique values:")
for field in idxFields:
    vals = set([getattr(acq.idx, field) for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  {field:20s} has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

for i in range(8):
    vals = set([acq.idx.user[i] for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  user[{i}]              has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

# Format data into single [cha PE RO rep] array
lin = [acq.idx.kspace_encode_step_1 for acq in imgAcqs]
rep = [acq.idx.repetition           for acq in imgAcqs]

raw = np.zeros((mrdHeader.acquisitionSystemInformation.receiverChannels, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.y, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.x, 
                mrdHeader.encoding[0].encodingLimits.repetition.maximum+1), 
                imgAcqs[0].data.dtype)

for acq, lin, rep in zip(imgAcqs, lin, rep):
    raw[:,lin,-acq.data.shape[1]:,rep] = acq.data

# Show the AcquisitionHeader flags for each line of k-space
print("Readouts with AcquisitionHeader flags present:")
acqFlags = [field for field in dir(ismrmrd) if field.startswith('ACQ_')]
for i, acq in enumerate(imgAcqs):
    strFlags = ", ".join([field for field in acqFlags if acq.is_flag_set(getattr(ismrmrd, field))])
    if strFlags:
        print(f'[{i:3d}] Lin {acq.idx.kspace_encode_step_1}: {strFlags}')

t = np.log(np.abs(raw[0,:,:,0]))
t[np.isinf(t)] = 0

dpi = 100
plt.figure(figsize=(3*t.shape[1] / dpi, 3*t.shape[0] / dpi), dpi=dpi)
plt.imshow(t, interpolation='nearest')
plt.title('Raw k-space (rep %d/%d, coil %d/%d)' % (1, mrdHeader.encoding[0].encodingLimits.repetition.maximum+1, 1, mrdHeader.acquisitionSystemInformation.receiverChannels))
# plt.axis('off')
plt.show()
# Out:
# File "data/MiniFLASH_Fire.mrd" contains 1 datasets:
#   dataset
# Reading dataset "dataset" from file "data/MiniFLASH_Fire.mrd"
# There are 128 imaging readouts out of a total of 128 readouts
# Loop index counters with unique values:
#   kspace_encode_step_1 has 128 unique values (min:   0, max: 127)
# Readouts with AcquisitionHeader flags present:
# [  0] Lin 0: ACQ_FIRST_IN_SLICE
# [127] Lin 127: ACQ_LAST_IN_MEASUREMENT, ACQ_LAST_IN_REPETITION, ACQ_LAST_IN_SLICE

# %% [markdown]
# ## Option 3: Convert a set of DICOMs
# For image processing workflows, it may also be useful to use DICOM images as input data.  These can be converted to MRD format using the [dicom2mrd.py](../dicom2mrd.py) script.  Not that the header information from data converted in this way may differ from data converted from the scanner.

# %%
# Folder containing DICOM files
import os
dicomFolder   = r'C:\Lung_Project\Measurements\CDH_Study\20251018_age10'
inputFilename = 'data/dicoms.mrd'

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

import dicom2mrd
from types import SimpleNamespace

# Adjust the logging configuration otherwise INFO level isn't shown in notebook output
import logging
logging.getLogger().setLevel(logging.INFO)

# Specify client arguments for recon
args = SimpleNamespace(**dicom2mrd.defaults)
args.folder   = dicomFolder
args.outFile  = inputFilename

dicom2mrd.main(args)
# Out:
# Found 1 unique series from 280 files in folder C:\Lung_Project\Measurements\CDH_Study\20251018_age10
# Creating MRD XML header from file C:\Lung_Project\Measurements\CDH_Study\20251018_age10\1.dcm
# <?xml version="1.0" encoding="ascii"?>
# <ismrmrdHeader xmlns="http://www.ismrm.org/ISMRMRD">
#  <studyInformation>
#   <studyDate>2025-10-28</studyDate>
#   <studyTime>09:47:16</studyTime>
#   <studyID>04879831</studyID>
#   <studyDescription>Kinderprotokolle Untersuchung_neu</studyDescription>
#   <studyInstanceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000297</studyInstanceUID>
#   <bodyPartExamined>LUNG</bodyPartExamined>
#  </studyInformation>
#  <measurementInformation>
#   <measurementID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000305</measurementID>
#   <patientPosition>HFS</patientPosition>
#   <protocolName>trufi_lung</protocolName>
#   <frameOfReferenceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000306</frameOfReferenceUID>
#  </measurementInformation>
#  <acquisitionSystemInformation>
#   <systemVendor>Siemens Healthineers</systemVendor>
#   <systemModel>MAGNETOM Aera</systemModel>
#   <systemFieldStrength_T>1.5</systemFieldStrength_T>
#  </acquisitionSystemInformation>
#  <experimentalConditions>
#   <H1resonanceFrequency_Hz>63870000</H1resonanceFrequency_Hz>
#  </experimentalConditions>
#  <encoding>
#   <encodedSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </encodedSpace>
#   <reconSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </reconSpace>
#   <encodingLimits/>
#   <trajectory>cartesian</trajectory>
#   <parallelImaging>
#    <accelerationFactor>
#     <kspace_encoding_step_1>3</kspace_encoding_step_1>
#     <kspace_encoding_step_2>1</kspace_encoding_step_2>
#    </accelerationFactor>
#   </parallelImaging>
#  </encoding>
#  <sequenceParameters>
#   <TR>2.06</TR>
#   <flipAngle_deg>30.0</flipAngle_deg>
#  </sequenceParameters>
#  <userParameters>
#   <userParameterDouble>
#    <name>ReadoutOS</name>
#    <value>2.0</value>
#   </userParameterDouble>
#  </userParameters>
# </ismrmrdHeader>
#
# Series 19 has 280 images with 1 slices and 1 phases
# Creating MRD file data/dicoms.mrd with group dataset

# %% [markdown]
# ## Option 4: Save data using server.py
# For inline integration with an MRI scanner or another data source, the conversion to MRD may be done with vendor-provided software.  In this case, it may be desirable to use MRD server in this repository to save a copy of data that it receives, particularly for development purposes.  The data can then be re-run with [client.py](../client.py).  This can be achieved by starting the server with [main.py](../main.py) with the `-s` (`--savedata`) option and data is stored in `/tmp/share/saved_data` unless overridden by the `-S` (`--savedataFolder`) option.

# %%
inputFilename = 'data/dicoms.mrd'

# %% [markdown]
# # Run reconstruction
# Algorithms/reconstructions are run as modules by the server component, which implements the [MRD streaming protocol](https://ismrmrd.readthedocs.io/en/latest/mrd_streaming_protocol.html).  The server must be started separately and a client sends data to the server for processing.  The server can be started via command line by running `python main.py`.
#
# If using Visual Studio Code, [launch.json](../.vscode/launch.json) includes a debug configuration to run the server and allow for interactive debugging.  Click on the "Run and Debug" tab on the top left, then click the green play button to start the desired config ("Start server"):
#
# ![image-2.png](attachment:image-2.png)
#
# Breakpoints can be set by clicking to the left of the line number in a Python file:
#
# ![image.png](attachment:image.png)
#
# After the server is started, begin the reconstruction by running [client.py](../client.py) on the input dataset.  The recon code/module is selected by using the `config` argument.  The output is stored in a separate MRD file under a dataset named with the current date/time.

# %%
# Import the MRD client to send data to server for reconstruction
import client
from types import SimpleNamespace

# Adjust the logging configuration, otherwise INFO level isn't shown in notebook output by default
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

import datetime
outputFilename = 'data/recon.mrd'

# Specify client arguments for recon
args = SimpleNamespace(**client.defaults)
args.config    = 'custom.Test1'  # Recon module to be used
args.port      = 9020
args.out_group = str(datetime.datetime.now())  # Set when using in notebook, otherwise out_group is time of first import of client module
args.outfile   = outputFilename
args.filename  = inputFilename

client.main(args)
# Out:
# 2026-05-28 06:54:58,419 - File data/dicoms.mrd contains 1 groups:
# 2026-05-28 06:54:58,419 - dataset
# 2026-05-28 06:54:58,420 - Reading data from group 'dataset' in file 'data/dicoms.mrd'
# 2026-05-28 06:54:58,422 - Connecting to MRD server at localhost:9020
# No logfile provided
# /usr/local/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=1345) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# 2026-05-28 06:54:58,437 - Sending remote config file name 'custom.Test1'
# 2026-05-28 06:54:58,439 - --> Sending MRD_MESSAGE_CONFIG_FILE (1)
# 2026-05-28 06:54:58,447 - --> Sending MRD_MESSAGE_METADATA_XML_TEXT (3)
# 2026-05-28 06:54:58,447 - Starting image data session
# 2026-05-28 06:54:58,448 - Reading images from '/dataset/image_0'
# 2026-05-28 06:54:58,468 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,474 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,479 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,485 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,491 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,496 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,502 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,509 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,902 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,910 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,915 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,923 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,928 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,934 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,940 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,946 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,952 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,957 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,962 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,968 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,974 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,979 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,985 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,991 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:58,996 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,006 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,011 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,017 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,023 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,028 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,034 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,039 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,045 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,051 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,056 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,062 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,067 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,073 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,078 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,088 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,093 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,098 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,104 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,109 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,114 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,121 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,126 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,131 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,138 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,143 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,149 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,154 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,160 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,165 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,172 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,177 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,182 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,188 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,194 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,201 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,206 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,212 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,226 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,237 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,246 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,254 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,261 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,269 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,275 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,283 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,289 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,295 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,302 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,308 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,313 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,319 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,325 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,331 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,337 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,342 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,348 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,353 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,358 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,364 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,369 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,374 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,379 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,384 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,389 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,394 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,401 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,406 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,411 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,416 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,421 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,426 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,431 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,437 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,442 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,448 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,453 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,458 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,464 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,470 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,474 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,482 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,488 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,493 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,499 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,504 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,509 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,514 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,520 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,525 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,531 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,536 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,541 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,547 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,552 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,557 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,562 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,567 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,572 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,577 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,583 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,588 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,592 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,598 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,603 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,609 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,615 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,620 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,625 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,630 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,635 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,640 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,645 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,650 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,656 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,661 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,667 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,672 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,677 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,683 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,688 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,693 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,698 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,704 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,709 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,714 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,720 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,725 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,731 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,736 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,742 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,748 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,754 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,759 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,765 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,770 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,776 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,781 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,786 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,791 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,797 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,802 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,807 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,818 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,828 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,834 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,840 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,847 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,854 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,860 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,867 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,873 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,880 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,886 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,892 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,898 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,904 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,910 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,918 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,923 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,928 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,934 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,939 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,944 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,949 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,955 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,960 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,965 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,970 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,975 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,985 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:54:59,993 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,003 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,011 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,020 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,031 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,039 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,046 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,054 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,062 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,070 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,077 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,084 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,090 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,096 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,103 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,110 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,117 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,123 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,130 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,136 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,142 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,148 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,154 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,161 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,167 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,173 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,178 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,184 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,189 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,195 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,201 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,205 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,210 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,217 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,223 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,228 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,234 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,240 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,245 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,251 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,259 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,266 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,283 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,294 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,299 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,305 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,310 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,316 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,321 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,326 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,332 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,338 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,343 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,349 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,354 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,360 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,366 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,371 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,377 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,382 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,388 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,394 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,400 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,407 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,413 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,419 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,425 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,431 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,437 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,443 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,449 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,456 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,461 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,469 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,476 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,482 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,487 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,493 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,498 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,504 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,509 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,515 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,521 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,526 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,532 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-28 06:55:00,533 - --> Sending MRD_MESSAGE_CLOSE (4)
# 2026-05-28 06:55:01,507 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,510 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,511 - Incoming data will be saved to: 'data/recon.mrd' in group '2026-05-28 06:54:58.416374'
# 2026-05-28 06:55:01,520 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,521 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,529 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,530 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,535 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,537 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,541 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,542 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,546 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,547 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,553 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,554 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,558 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,560 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,565 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,566 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,581 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,583 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,587 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,588 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,592 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,592 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,597 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,599 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,603 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,604 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,608 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,609 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,614 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,615 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,622 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,623 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,639 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,641 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,646 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,648 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,652 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,653 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,658 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,659 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,664 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,665 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,670 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,671 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,675 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,676 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,681 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,682 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,702 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,704 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,717 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,719 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,727 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,729 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,735 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,736 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,741 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,742 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,749 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,750 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,755 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,756 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,761 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,762 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,776 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,777 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,782 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,784 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,788 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,789 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,795 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,796 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,802 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,803 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,808 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,809 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,813 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,815 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,820 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,821 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,835 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,836 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,840 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,841 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,846 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,847 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,852 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,853 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,857 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,858 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,862 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,864 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,868 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,869 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,873 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,874 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,887 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,888 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,892 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,893 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,898 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,899 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,903 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,905 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,909 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,910 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,915 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,916 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,920 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,921 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,926 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,927 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,940 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,941 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,946 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,947 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,951 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,952 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,958 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,959 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,963 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,964 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,970 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,971 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,975 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,976 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,981 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,982 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:01,996 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:01,997 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,002 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,003 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,007 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,008 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,014 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,015 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,019 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,020 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,024 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,025 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,029 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,031 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,036 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,037 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,050 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,052 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,056 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,057 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,061 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,062 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,067 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,069 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,073 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,074 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,078 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,080 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,084 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,085 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,090 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,091 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,103 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,105 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,109 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,110 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,114 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,115 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,120 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,121 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,125 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,126 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,131 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,132 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,137 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,138 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,143 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,144 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,157 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,158 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,163 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,164 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,168 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,169 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,174 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,176 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,180 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,181 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,186 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,187 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,191 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,192 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,198 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,199 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,212 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,213 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,217 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,218 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,222 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,223 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,228 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,229 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,233 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,234 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,239 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,240 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,246 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,247 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,263 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,264 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,282 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,283 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,288 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,289 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,294 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,295 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,301 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,303 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,307 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,309 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,315 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,316 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,321 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,323 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,328 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,329 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,343 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,344 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,349 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,350 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,354 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,355 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,360 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,361 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,366 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,367 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,371 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,372 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,377 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,378 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,383 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,384 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,425 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,426 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,433 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,434 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,439 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,440 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,446 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,447 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,452 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,454 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,460 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,461 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,466 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,467 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,472 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,473 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,487 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,488 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,492 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,493 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,497 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,498 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,503 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,504 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,509 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,510 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,515 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,516 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,520 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,522 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,527 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,528 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,540 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,542 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,546 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,547 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,551 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,552 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,557 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,558 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,562 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,563 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,568 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,569 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,573 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,575 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,580 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,581 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,594 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,595 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,599 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,600 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,604 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,605 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,609 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,611 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,615 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# ...
# 2026-05-28 06:55:02,870 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,871 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,875 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,876 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,882 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,883 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,898 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,899 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,911 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,913 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,921 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,923 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,941 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,942 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,947 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,948 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,953 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,954 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,959 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,960 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,964 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,965 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,970 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,972 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,976 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,977 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,982 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,984 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:02,996 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:02,997 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,001 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,002 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,006 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,007 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,013 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,014 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,019 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,020 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,024 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,025 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,030 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,031 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,035 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,036 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,048 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,050 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,053 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,054 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,058 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,059 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,064 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,065 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,069 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,070 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,074 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,075 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,080 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,081 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,085 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,087 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,099 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,100 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,104 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,105 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,109 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,110 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,114 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,116 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,120 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,121 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,125 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,126 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,130 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,131 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,135 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,136 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,149 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,151 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,155 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,156 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,160 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,161 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,166 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,167 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,171 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,172 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,177 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,178 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,182 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,183 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,188 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,189 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,202 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,203 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,207 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,208 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,212 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,214 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,221 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,222 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,227 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,229 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,234 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,235 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,239 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,240 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,245 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,247 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,259 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,260 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,265 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,266 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,270 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,271 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,276 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,277 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,281 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,282 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,287 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,289 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,294 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,295 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,299 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,301 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,313 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,314 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,319 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,320 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,324 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,325 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,329 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,330 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,334 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,335 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,340 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,341 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,345 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,346 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,351 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,352 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,369 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,371 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,386 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,387 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,397 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,398 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,404 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,406 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,414 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,415 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,421 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,422 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,427 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,429 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,434 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,435 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,451 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,453 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,457 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,458 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,463 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,464 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,470 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,471 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,476 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,477 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,482 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,483 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,487 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,489 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,494 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,496 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,511 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,512 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,517 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,518 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,522 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,523 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,527 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,529 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,533 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,534 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,538 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,539 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,544 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,545 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-28 06:55:03,549 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-28 06:55:03,550 -     Image is size 256 x 256 x 1 with 1 channels of type float64
# 2026-05-28 06:55:03,565 - <-- Received MRD_MESSAGE_CLOSE (4)
# 2026-05-28 06:55:03,566 -     Total received acquisitions:     0
# 2026-05-28 06:55:03,567 -     Total received images:         281
# 2026-05-28 06:55:03,567 -     Total received waveforms:        0
# 2026-05-28 06:55:03,568 - ------------------------------------------
# 2026-05-28 06:55:03,572 - Socket closed (writer)
# 2026-05-28 06:55:03,579 - ---------------------- Summary ----------------------
# 2026-05-28 06:55:03,580 - Sent     0 acquisitions  |  Received     0 acquisitions
# 2026-05-28 06:55:03,580 - Sent   280 images        |  Received   281 images
# 2026-05-28 06:55:03,581 - Sent     0 waveforms     |  Received     0 waveforms
# 2026-05-28 06:55:03,581 - Results written to data/recon.mrd
# 2026-05-28 06:55:03,581 - Session complete

# %% [markdown]
# # Display the reconstructed/processed images
# The output is an [HDF5-formatted file](https://www.hdfgroup.org/downloads/hdfview/) that is organized in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html).  It can be opened using MRD toolboxes for [python](https://github.com/ismrmrd/ismrmrd-python) or [MATLAB](https://github.com/ismrmrd/ismrmrd/tree/master/matlab/%2Bismrmrd) or the [ismrmrdviewer](https://github.com/ismrmrd/ismrmrdviewer).  The client can be run multiple times with the same output file and results are grouped by dataset.

# %%
# Display the reconstructed images
import h5py
import ismrmrd
import mrdhelper
import numpy as np
import matplotlib.pyplot as plt
import re

# Uncomment to display images from a different output file
outputFilename = 'data/recon.mrd'

# If run multiple times, the recon.mrd file will have multiple reconstructed images
# Find the most recent recon run
with h5py.File(outputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File %s contains %d groups (reconstruction runs):' % (outputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[-1]

with ismrmrd.Dataset(outputFilename, group, False) as dset:
    subgroups = dset.list()

    # Images are organized by series number in subgroups that start with 'image_' or 'images_'
    imgGroups = [group for group in list(subgroups) if (group.find('image_') != -1) or (group.find('images_') != -1)]
    imgGroupsWithNumImages = [f'{group} ({dset.number_of_images(group)} image{"s"[:dset.number_of_images(group)^1]})' for group in imgGroups]
    print('Group %s contains %d image series:' % (group, len(imgGroups)))
    print(' ', '\n  '.join(imgGroupsWithNumImages))

    # Show images
    fig, axs = plt.subplots(nrows=1, ncols=len(imgGroups), squeeze=False, figsize=(10,5))

    for i, series in enumerate(imgGroups):
        n = dset.number_of_images(series)
        img = dset.read_image(series, 0)
        meta = ismrmrd.Meta.deserialize(img.attribute_string)

        seriesNumber = re.search(r'(?<=_)\d+$', series).group(0)
        title = f'Series {re.search(r'(?<=_)\d+$', series).group(0)}, Image 1/{n}'
        if 'ImageComments' in meta.keys():
            title += '\n' + meta['ImageComments']

        axs[0][i].imshow(np.squeeze(img.data), cmap='gray')
        axs[0][i].set_title(title)
        axs[0][i].axis('off')
        axs[0][i].set_aspect('equal')

        # Read and plot ROIs
        for key in meta.keys():
            if not key.startswith('ROI_'):
                continue

            roi = meta[key]
            x, y, rgb, thickness, style, visibility = mrdhelper.parse_roi(roi)

            if visibility == 0:
                continue

            lstyle = '-' if (style == 0) else '--'
            axs[0][i].plot(x, y, color=rgb, linewidth=thickness, linestyle=lstyle)
        
        maxKeyLen = max([len(key) for key in meta.keys()])
        print("MetaAttributes:")
        for key, value in meta.items():
            print(f'  {key:{maxKeyLen}} : {value}')

    # Adjust layout to prevent clipping of titles
    plt.tight_layout(pad=0.5)

    plt.show()
# Out:
# File data/recon.mrd contains 18 groups (reconstruction runs):
#   2026-05-20 11:37:04.996605
#   2026-05-20 11:40:43.435208
#   2026-05-20 11:41:33.930310
#   2026-05-20 11:47:38.941154
#   2026-05-20 11:57:39.407014
#   2026-05-20 11:58:28.853187
#   2026-05-20 12:13:00.200305
#   2026-05-20 13:00:18.938511
#   2026-05-20 13:04:31.928644
#   2026-05-20 13:09:15.975190
#   2026-05-21 06:24:47.192308
#   2026-05-21 13:36:42.627658
#   2026-05-26 09:39:06.155202
#   2026-05-26 09:42:26.819942
#   2026-05-26 09:46:59.448153
#   2026-05-26 12:29:17.912177
#   2026-05-28 06:44:51.754226
#   2026-05-28 06:54:58.416374
# Group 2026-05-28 06:54:58.416374 contains 2 image series:
#   image_0 (1 image)
#   image_99 (280 images)
# MetaAttributes:
#   ImageType                     : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription           : trufi_lung
#   DicomJson                     : ...
#   DataRole                      : Image
#   ImageProcessingHistory        : ['PYTHON', 'INVERT']
#   WindowCenter                  : 2048.0
#   WindowWidth                   : 4096
#   SequenceDescriptionAdditional : FIRE
#   Keep_image_geometry           : 1
#   ImageRowDir                   : ['1.000000000000000000', '-0.000143149998621084', '0.000000000000083000']
#   ImageColumnDir                : ['0.000006547859811690', '0.045741301029920578', '-0.998952984809875488']
# MetaAttributes:
#   ImageType           : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription : trufi_lung
#   DicomJson           : ...
#   Keep_image_geometry : 1
# /usr/local/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
