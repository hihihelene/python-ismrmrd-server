# %% [markdown]
# # Create/convert an input dataset in MRD format
#
# Prepare a dataset in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html) by converting acquired data or by generating a synthetic phantom dataset.  Raw k-space data can be converted using tools such as [siemens_to_ismrmrd](https://github.com/ismrmrd/siemens_to_ismrmrd), [ge_to_ismrmrd](https://github.com/ismrmrd/ge_to_ismrmrd), [philips_to_ismrmrd](https://github.com/ismrmrd/philips_to_ismrmrd), and [bruker_to_ismrmrd](https://github.com/ismrmrd/bruker_to_ismrmrd), while DICOM image data can be converted to DICOM using [dicom2mrd.py](https://github.com/kspaceKelvin/python-ismrmrd-server#UsingDICOMimagesasinputdata).  The [generate_cartesian_shepp_logan_dataset.py](../generate_cartesian_shepp_logan_dataset.py) script can also be used to generate multi-channel raw k-space data.

# %% [markdown]
# ## Option 1: Simulate a raw k-space dataset of the Shepp-Logan phantom
# **Note** This section requires that the [ismrmrd-python-tools](https://github.com/ismrmrd/ismrmrd-python-tools) repo be installed (see [readme.md](../readme.md#Settingupacondaenvironment))

# %%
# Generate a raw k-space dataset of the Shepp-Logan phantom
import os
import generate_cartesian_shepp_logan_dataset

inputFilename = 'data/raw.mrd'

dir, file = os.path.split(inputFilename)
if dir and not os.path.exists(dir):
    print(f'Creating parent directory {dir}')
    os.makedirs(dir)

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

generate_cartesian_shepp_logan_dataset.create(filename=inputFilename, matrix_size=256, coils=8, oversampling=2, repetitions=1, acceleration=1, noise_level=0.05)
# Out:
# Creating Shepp-Logan phantom raw data:
# Matrix 256x256 at R=1 with 1 repetitions
# 8 coils with 2 oversampling and 0.05 noise level
# Saved to data/raw.mrd

# %% [markdown]
# ## Option 2: Convert raw k-space data acquired from an MRI scanner

# %%
# Run siemens_to_ismrmrd to convert a .dat file into MRD format
# Note that as there is no Windows executable, this must be run in Linux or in a devcontainer

# Relative path to Siemens .dat file (note this .ipynb file likely exists in the doc subfolder!)
datFile = 'data/MiniFLASH_Fire.dat'

# Measurement in the multi-RAID .dat file to convert.  Note the .dat file may contain dependent
# scans, e.g. AdjCoilSens and the desired scan is usually the last in the multi-RAID file
# Negative indices are relative to the end (e.g. -1 for the last measurement)
measNum = '-1'

# Parameter map and stylesheet to use to convert from Siemens parameter buffers to an MRD header.
# These can specify a relative path to local files or files embedded inside siemens_to_ismrmrd.
# These arguments can also be omitted and will default to these values.
paramMap      = None
paramMapStyle = None

# The output file can be specified with the "--output" option, but will be named with the same
# filename as the input file (with a .mrd extension) if omitted.

import subprocess
import os

inputFilename = os.path.splitext(datFile)[0] + '.mrd'
if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

command = ['siemens_to_ismrmrd', '--measNum', measNum, '--file', datFile]
if paramMap is not None:
    command.extend(('--pMap', paramMap))

if paramMapStyle is not None:
    command.extend(('--pMapStyle', paramMapStyle))

try:
    result = subprocess.run(command, check=True, text=True, capture_output=True)
    print("Output:", result.stdout)
except subprocess.CalledProcessError as e:
    raise Exception("Error:", e.stderr)
# Out:
# Output: Siemens file is: data/MiniFLASH_Fire.dat
# Output file not specified -- using data/MiniFLASH_Fire.mrd
# -----------------------------------------------------------------
# Converting measurement 1 into file data/MiniFLASH_Fire.mrd in group dataset
# -----------------------------------------------------------------
# Using parameter map: IsmrmrdParameterMap_Siemens.xml
# This file contains 1 measurement(s).
# VD line file detected.
# Protocol name [1]: MiniFLASH_Fire
# Number of parameter buffers: 6
# Buffer Name: Config
# Buffer Name: Dicom
# Buffer Name: Meas
# Buffer Name: MeasYaps
# Buffer Name: Phoenix
# Buffer Name: Spice
# Trajectory is: 1
# Failed to find YAPS.lFirstFourierLine array
# Failed to find YAPS.lFirstFourierPartition array
# center_line = 64
# center_partition = 0
# Baseline: N4_VE11C_LATEST_20160120
# Software version: syngo MR E11
# Protocol name: MiniFLASH_Fire
# Dwell time: 15000
# Using parameter XSL: IsmrmrdParameterMap_Siemens.xsl
# Study time: 16:06:09
# Last scan reached...

# %% [markdown]
# ## Visualize raw k-space data
# Inspect and visualize the raw k-space dataset using the [ismrmrd-python](https://github.com/ismrmrd/ismrmrd-python) library.  Data from multiple scans/acquisitions can be stored in a single file, grouped in ['datasets'](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html#mrd-file-format).  The datasets in a file can be listed with:

# %%
# Display the generated raw k-space data
import h5py
import ismrmrd
import numpy as np
import matplotlib.pyplot as plt

datasetName = 'dataset'

# List all datasets in the file
with h5py.File(inputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File "%s" contains %d datasets:' % (inputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[0]

    datasetName = list(d.keys())[0]

print('Reading dataset "%s" from file "%s"' % (datasetName, inputFilename))
with ismrmrd.Dataset(inputFilename, datasetName, False) as dset:
    # Read MRD header
    xmlHeader = dset.read_xml_header().decode('utf-8')
    mrdHeader = ismrmrd.xsd.CreateFromDocument(xmlHeader)

    # Get all readouts
    acqs = [dset.read_acquisition(idx) for idx in range(dset.number_of_acquisitions())]

    # Limit to imaging (non-noise) readouts
    imgAcqs = [acq for acq in acqs if not acq.is_flag_set(ismrmrd.ACQ_IS_NOISE_MEASUREMENT)]

    print('There are %d imaging readouts out of a total of %d readouts' % (len(imgAcqs), dset.number_of_acquisitions()))

# List index counters that have >1 unique values
idxFields = ['average', 'contrast', 'kspace_encode_step_1', 'kspace_encode_step_2', 'phase', 'repetition', 'segment', 'set', 'slice']
print("Loop index counters with unique values:")
for field in idxFields:
    vals = set([getattr(acq.idx, field) for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  {field:20s} has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

for i in range(8):
    vals = set([acq.idx.user[i] for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  user[{i}]              has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

# Format data into single [cha PE RO rep] array
lin = [acq.idx.kspace_encode_step_1 for acq in imgAcqs]
rep = [acq.idx.repetition           for acq in imgAcqs]

raw = np.zeros((mrdHeader.acquisitionSystemInformation.receiverChannels, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.y, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.x, 
                mrdHeader.encoding[0].encodingLimits.repetition.maximum+1), 
                imgAcqs[0].data.dtype)

for acq, lin, rep in zip(imgAcqs, lin, rep):
    raw[:,lin,-acq.data.shape[1]:,rep] = acq.data

# Show the AcquisitionHeader flags for each line of k-space
print("Readouts with AcquisitionHeader flags present:")
acqFlags = [field for field in dir(ismrmrd) if field.startswith('ACQ_')]
for i, acq in enumerate(imgAcqs):
    strFlags = ", ".join([field for field in acqFlags if acq.is_flag_set(getattr(ismrmrd, field))])
    if strFlags:
        print(f'[{i:3d}] Lin {acq.idx.kspace_encode_step_1}: {strFlags}')

t = np.log(np.abs(raw[0,:,:,0]))
t[np.isinf(t)] = 0

dpi = 100
plt.figure(figsize=(3*t.shape[1] / dpi, 3*t.shape[0] / dpi), dpi=dpi)
plt.imshow(t, interpolation='nearest')
plt.title('Raw k-space (rep %d/%d, coil %d/%d)' % (1, mrdHeader.encoding[0].encodingLimits.repetition.maximum+1, 1, mrdHeader.acquisitionSystemInformation.receiverChannels))
# plt.axis('off')
plt.show()
# Out:
# File "data/MiniFLASH_Fire.mrd" contains 1 datasets:
#   dataset
# Reading dataset "dataset" from file "data/MiniFLASH_Fire.mrd"
# There are 128 imaging readouts out of a total of 128 readouts
# Loop index counters with unique values:
#   kspace_encode_step_1 has 128 unique values (min:   0, max: 127)
# Readouts with AcquisitionHeader flags present:
# [  0] Lin 0: ACQ_FIRST_IN_SLICE
# [127] Lin 127: ACQ_LAST_IN_MEASUREMENT, ACQ_LAST_IN_REPETITION, ACQ_LAST_IN_SLICE

# %% [markdown]
# ## Option 3: Convert a set of DICOMs
# For image processing workflows, it may also be useful to use DICOM images as input data.  These can be converted to MRD format using the [dicom2mrd.py](../dicom2mrd.py) script.  Not that the header information from data converted in this way may differ from data converted from the scanner.

# %%
# Folder containing DICOM files
import os
dicomFolder   = r'C:\Lung_Project\Measurements\CDH_Study\20251018_age10'
inputFilename = 'data/dicoms.mrd'

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

import dicom2mrd
from types import SimpleNamespace

# Adjust the logging configuration otherwise INFO level isn't shown in notebook output
import logging
logging.getLogger().setLevel(logging.INFO)

# Specify client arguments for recon
args = SimpleNamespace(**dicom2mrd.defaults)
args.folder   = dicomFolder
args.outFile  = inputFilename

dicom2mrd.main(args)
# Out:
# Found 1 unique series from 280 files in folder C:\Lung_Project\Measurements\CDH_Study\20251018_age10
# Creating MRD XML header from file C:\Lung_Project\Measurements\CDH_Study\20251018_age10\1.dcm
# <?xml version="1.0" encoding="ascii"?>
# <ismrmrdHeader xmlns="http://www.ismrm.org/ISMRMRD">
#  <studyInformation>
#   <studyDate>2025-10-28</studyDate>
#   <studyTime>09:47:16</studyTime>
#   <studyID>04879831</studyID>
#   <studyDescription>Kinderprotokolle Untersuchung_neu</studyDescription>
#   <studyInstanceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000297</studyInstanceUID>
#   <bodyPartExamined>LUNG</bodyPartExamined>
#  </studyInformation>
#  <measurementInformation>
#   <measurementID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000305</measurementID>
#   <patientPosition>HFS</patientPosition>
#   <protocolName>trufi_lung</protocolName>
#   <frameOfReferenceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000306</frameOfReferenceUID>
#  </measurementInformation>
#  <acquisitionSystemInformation>
#   <systemVendor>Siemens Healthineers</systemVendor>
#   <systemModel>MAGNETOM Aera</systemModel>
#   <systemFieldStrength_T>1.5</systemFieldStrength_T>
#  </acquisitionSystemInformation>
#  <experimentalConditions>
#   <H1resonanceFrequency_Hz>63870000</H1resonanceFrequency_Hz>
#  </experimentalConditions>
#  <encoding>
#   <encodedSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </encodedSpace>
#   <reconSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </reconSpace>
#   <encodingLimits/>
#   <trajectory>cartesian</trajectory>
#   <parallelImaging>
#    <accelerationFactor>
#     <kspace_encoding_step_1>3</kspace_encoding_step_1>
#     <kspace_encoding_step_2>1</kspace_encoding_step_2>
#    </accelerationFactor>
#   </parallelImaging>
#  </encoding>
#  <sequenceParameters>
#   <TR>2.06</TR>
#   <flipAngle_deg>30.0</flipAngle_deg>
#  </sequenceParameters>
#  <userParameters>
#   <userParameterDouble>
#    <name>ReadoutOS</name>
#    <value>2.0</value>
#   </userParameterDouble>
#  </userParameters>
# </ismrmrdHeader>
#
# Series 19 has 280 images with 1 slices and 1 phases
# Creating MRD file data/dicoms.mrd with group dataset

# %% [markdown]
# ## Option 4: Save data using server.py
# For inline integration with an MRI scanner or another data source, the conversion to MRD may be done with vendor-provided software.  In this case, it may be desirable to use MRD server in this repository to save a copy of data that it receives, particularly for development purposes.  The data can then be re-run with [client.py](../client.py).  This can be achieved by starting the server with [main.py](../main.py) with the `-s` (`--savedata`) option and data is stored in `/tmp/share/saved_data` unless overridden by the `-S` (`--savedataFolder`) option.

# %%
inputFilename = 'data/dicoms.mrd'

# %% [markdown]
# # Run reconstruction
# Algorithms/reconstructions are run as modules by the server component, which implements the [MRD streaming protocol](https://ismrmrd.readthedocs.io/en/latest/mrd_streaming_protocol.html).  The server must be started separately and a client sends data to the server for processing.  The server can be started via command line by running `python main.py`.
#
# If using Visual Studio Code, [launch.json](../.vscode/launch.json) includes a debug configuration to run the server and allow for interactive debugging.  Click on the "Run and Debug" tab on the top left, then click the green play button to start the desired config ("Start server"):
#
# ![image-2.png](attachment:image-2.png)
#
# Breakpoints can be set by clicking to the left of the line number in a Python file:
#
# ![image.png](attachment:image.png)
#
# After the server is started, begin the reconstruction by running [client.py](../client.py) on the input dataset.  The recon code/module is selected by using the `config` argument.  The output is stored in a separate MRD file under a dataset named with the current date/time.

# %%
# Import the MRD client to send data to server for reconstruction
import client
from types import SimpleNamespace

# Adjust the logging configuration, otherwise INFO level isn't shown in notebook output by default
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

import datetime
outputFilename = 'data/recon.mrd'

# Specify client arguments for recon
args = SimpleNamespace(**client.defaults)
args.config    = 'custom.MAIN_VQMap'  # Recon module to be used
args.port      = 9020
args.out_group = str(datetime.datetime.now())  # Set when using in notebook, otherwise out_group is time of first import of client module
args.outfile   = outputFilename
args.filename  = inputFilename

client.main(args)
# Out:
# 2026-06-29 12:13:00,493 - File data/dicoms.mrd contains 1 groups:
# 2026-06-29 12:13:00,494 - dataset
# 2026-06-29 12:13:00,495 - Reading data from group 'dataset' in file 'data/dicoms.mrd'
# 2026-06-29 12:13:00,497 - Connecting to MRD server at localhost:9020
# No logfile provided
# 2026-06-29 12:13:00,502 - Sending remote config file name 'custom.MAIN_VQMap'
# 2026-06-29 12:13:00,505 - --> Sending MRD_MESSAGE_CONFIG_FILE (1)
# 2026-06-29 12:13:00,514 - --> Sending MRD_MESSAGE_METADATA_XML_TEXT (3)
# 2026-06-29 12:13:00,515 - Starting image data session
# 2026-06-29 12:13:00,516 - Reading images from '/dataset/image_0'
# 2026-06-29 12:13:00,531 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:00,540 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:00,548 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:00,556 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:00,562 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:00,578 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:00,584 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,008 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,015 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,020 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,027 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,033 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,039 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,044 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,051 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,056 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,061 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,068 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,073 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,079 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,085 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,090 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,096 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,102 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,107 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,113 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,119 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,124 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,131 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,136 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,141 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,147 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,152 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,157 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,162 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,169 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,173 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,179 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,185 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,190 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,197 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,202 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,207 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,213 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,219 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,225 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,233 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,242 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,249 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,254 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,260 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,267 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,273 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,279 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,285 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,290 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,296 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,302 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,307 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,313 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,319 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,324 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,330 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,335 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,340 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,347 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,352 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,357 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,362 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,368 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,373 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,379 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,384 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,389 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,395 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,401 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,406 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,412 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,418 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,423 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,428 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,434 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,440 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,445 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,451 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,456 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,462 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,467 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,474 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,480 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,485 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,490 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,496 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,502 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,507 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,512 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,518 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,523 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,530 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,535 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,540 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,546 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,551 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,557 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,562 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,569 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,574 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,580 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,586 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,591 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,596 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,602 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,607 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,613 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,618 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,624 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,630 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,636 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,641 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,648 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,653 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,658 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,663 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,669 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,674 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,681 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,686 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,691 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,697 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,702 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,707 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,714 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,719 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,724 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,732 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,737 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,741 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,748 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,753 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,758 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,764 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,769 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,774 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,780 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,786 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,790 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,796 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,802 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,806 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,811 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,817 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,822 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,827 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,832 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,837 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,853 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,859 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,868 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,875 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,883 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,889 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,899 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,907 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,916 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,923 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,931 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,937 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,944 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,951 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,958 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,965 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,972 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,979 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,986 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,992 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:01,999 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,005 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,011 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,018 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,023 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,030 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,036 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,041 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,048 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,053 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,058 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,065 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,070 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,075 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,082 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,087 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,092 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,099 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,104 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,109 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,116 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,121 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,126 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,131 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,137 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,141 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,148 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,154 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,159 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,165 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,170 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,175 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,185 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,191 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,198 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,204 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,210 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,216 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,222 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,229 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,235 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,241 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,247 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,253 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,258 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,264 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,270 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,275 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,281 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,287 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,292 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,298 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,304 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,309 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,316 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,321 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,326 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,332 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,337 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,342 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,348 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,354 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,359 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,364 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,370 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,375 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,380 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,386 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,391 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,397 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,403 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,407 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,414 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,419 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,426 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,433 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,438 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,445 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,450 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,456 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,462 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,468 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,473 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,480 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,485 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,491 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,497 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,503 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,508 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,514 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,520 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,525 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,530 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,536 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,541 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,547 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,553 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,558 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,564 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,570 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,575 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,581 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,586 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,591 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,598 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-29 12:13:02,600 - --> Sending MRD_MESSAGE_CLOSE (4)
# 2026-06-29 12:13:54,628 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,631 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,632 - Incoming data will be saved to: 'data/recon.mrd' in group '2026-06-29 12:13:00.488793'
# 2026-06-29 12:13:54,643 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,645 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,653 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,654 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,661 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,662 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,669 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,670 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,677 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,679 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,686 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,687 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,694 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,696 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,703 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,704 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,711 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,712 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,730 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,731 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,737 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,738 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,746 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,747 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,754 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,755 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,762 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,764 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,771 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,772 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,779 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,780 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,787 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,788 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,795 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,797 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,815 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,816 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,823 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,824 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,832 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,833 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,840 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,841 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,849 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,850 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,858 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,859 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,868 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,869 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,876 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,877 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,885 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,886 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,904 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,905 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,912 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,913 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,923 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,924 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,933 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,934 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,941 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,943 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,954 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,955 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,962 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,963 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,971 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,972 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,979 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,980 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:54,998 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:54,999 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,006 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,007 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,015 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,016 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,023 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,025 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,034 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,035 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,047 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,049 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,060 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,061 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,073 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,074 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,085 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,087 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,108 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,109 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,118 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,119 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,127 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,128 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,136 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,138 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,144 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,145 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,183 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,184 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,202 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,203 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,209 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,210 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,220 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,221 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,238 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,240 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,248 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,249 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,257 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,258 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,268 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,269 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,275 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,276 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,285 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,286 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,292 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,293 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,302 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,303 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,309 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,310 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,328 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,330 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,337 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,338 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,347 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,348 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,354 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,355 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,363 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,364 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,371 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,372 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,381 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,382 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,388 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,389 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,398 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,399 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,417 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,418 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,424 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,425 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,431 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,432 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,440 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,441 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,450 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,451 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,458 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,459 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,467 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,469 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,475 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,476 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,484 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,485 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,503 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,504 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,511 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,512 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,519 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,520 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,527 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,527 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,535 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,536 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,544 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,545 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,552 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,554 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,560 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,561 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,570 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,571 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,589 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,591 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,598 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,599 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,606 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,607 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,614 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,615 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,623 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,624 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,631 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,632 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,639 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,640 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,647 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,648 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,654 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,655 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,673 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,674 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,681 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,682 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,689 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,690 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,696 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,698 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,706 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,707 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,713 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,714 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,722 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,723 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,730 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,731 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,738 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,739 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,756 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,757 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,767 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,768 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,776 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,777 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,785 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,786 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,793 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,794 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,803 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,804 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,811 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,812 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,819 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,820 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,826 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,827 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,844 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,845 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,851 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,853 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,859 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,861 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,867 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,868 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,878 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,880 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,886 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,887 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,893 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,895 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,901 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,902 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,909 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,911 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,932 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,933 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,942 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,943 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,953 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,955 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,965 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,966 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,975 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,976 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:55,987 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:55,988 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,000 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,001 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,010 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,011 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,020 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,021 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,042 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,043 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,052 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,054 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,062 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,064 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,073 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,074 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,083 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,084 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,093 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,094 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,102 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,104 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,110 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,112 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,120 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,121 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,142 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,143 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,152 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,153 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,166 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,167 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,175 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,176 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,186 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,187 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,195 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# ...
# 2026-06-29 12:13:56,725 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,727 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,739 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,741 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,766 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,768 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,776 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,778 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,788 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,789 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,799 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,800 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,809 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,810 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,821 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,822 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,833 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,835 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,846 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,847 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,857 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,859 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,886 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,887 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,897 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,898 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,908 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,910 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,923 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,925 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,936 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,937 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,948 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,949 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,959 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,960 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,970 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,971 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:56,980 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:56,982 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,008 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,009 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,019 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,020 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,030 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,032 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,042 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,043 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,053 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,055 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,064 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,066 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,074 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,075 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,085 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,086 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,094 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,095 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,116 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,118 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,125 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,127 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,136 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,137 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,145 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,146 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,156 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,157 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,169 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,171 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,183 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,184 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,244 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,246 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,257 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,258 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,282 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,283 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,291 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,292 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,301 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,302 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,310 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,311 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,321 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,322 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,332 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,334 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,347 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,349 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,363 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,365 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,378 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,380 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,409 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,410 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,422 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,423 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,435 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,436 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,446 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,448 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,458 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,459 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,470 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,471 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,482 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,483 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,493 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,494 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,506 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,507 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,535 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,536 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,544 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,546 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,555 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,556 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,566 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,567 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,576 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,577 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,588 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,589 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,602 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,603 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,612 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,614 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,624 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,626 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,652 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,653 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,662 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,664 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,674 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,675 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,689 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,690 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,704 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,706 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,719 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,721 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,734 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,735 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,746 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,748 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,761 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,763 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,790 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,791 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,802 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,803 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,814 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,816 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,825 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,826 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,838 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,839 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,852 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,853 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,865 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,866 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,877 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,878 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,890 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,891 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,925 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,926 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,940 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,943 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,960 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,963 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,977 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,979 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:57,995 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:57,997 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:58,009 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:58,010 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:58,024 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:58,025 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:58,038 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:58,039 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:58,053 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:58,054 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:58,082 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:58,083 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:58,093 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-29 12:13:58,094 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-29 12:13:58,105 - <-- Received MRD_MESSAGE_CLOSE (4)
# 2026-06-29 12:13:58,105 -     Total received acquisitions:     0
# 2026-06-29 12:13:58,106 -     Total received images:         282
# 2026-06-29 12:13:58,107 -     Total received waveforms:        0
# 2026-06-29 12:13:58,107 - ------------------------------------------
# 2026-06-29 12:13:58,119 - Socket closed (writer)
# 2026-06-29 12:13:58,133 - ---------------------- Summary ----------------------
# 2026-06-29 12:13:58,133 - Sent     0 acquisitions  |  Received     0 acquisitions
# 2026-06-29 12:13:58,134 - Sent   280 images        |  Received   282 images
# 2026-06-29 12:13:58,134 - Sent     0 waveforms     |  Received     0 waveforms
# 2026-06-29 12:13:58,135 - Results written to data/recon.mrd
# 2026-06-29 12:13:58,135 - Session complete

# %% [markdown]
# # Display the reconstructed/processed images
# The output is an [HDF5-formatted file](https://www.hdfgroup.org/downloads/hdfview/) that is organized in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html).  It can be opened using MRD toolboxes for [python](https://github.com/ismrmrd/ismrmrd-python) or [MATLAB](https://github.com/ismrmrd/ismrmrd/tree/master/matlab/%2Bismrmrd) or the [ismrmrdviewer](https://github.com/ismrmrd/ismrmrdviewer).  The client can be run multiple times with the same output file and results are grouped by dataset.

# %%
# Display the reconstructed images
import h5py
import ismrmrd
import mrdhelper
import numpy as np
import matplotlib.pyplot as plt
import re

# Uncomment to display images from a different output file
outputFilename = 'data/recon.mrd'

# If run multiple times, the recon.mrd file will have multiple reconstructed images
# Find the most recent recon run
with h5py.File(outputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File %s contains %d groups (reconstruction runs):' % (outputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[-1]

with ismrmrd.Dataset(outputFilename, group, False) as dset:
    subgroups = dset.list()

    # Images are organized by series number in subgroups that start with 'image_' or 'images_'
    imgGroups = [group for group in list(subgroups) if (group.find('image_') != -1) or (group.find('images_') != -1)]
    imgGroupsWithNumImages = [f'{group} ({dset.number_of_images(group)} image{"s"[:dset.number_of_images(group)^1]})' for group in imgGroups]
    print('Group %s contains %d image series:' % (group, len(imgGroups)))
    print(' ', '\n  '.join(imgGroupsWithNumImages))

    # Show images
    fig, axs = plt.subplots(nrows=1, ncols=len(imgGroups), squeeze=False, figsize=(10,5))

    for i, series in enumerate(imgGroups):
        n = dset.number_of_images(series)
        img = dset.read_image(series, 0)
        meta = ismrmrd.Meta.deserialize(img.attribute_string)

        seriesNumber = re.search(r'(?<=_)\d+$', series).group(0)
        title = f'Series {re.search(r'(?<=_)\d+$', series).group(0)}, Image 1/{n}'
        if 'ImageComments' in meta.keys():
            title += '\n' + meta['ImageComments']

        axs[0][i].imshow(np.squeeze(img.data), cmap='gray')
        axs[0][i].set_title(title)
        axs[0][i].axis('off')
        axs[0][i].set_aspect('equal')

        # Read and plot ROIs
        for key in meta.keys():
            if not key.startswith('ROI_'):
                continue

            roi = meta[key]
            x, y, rgb, thickness, style, visibility = mrdhelper.parse_roi(roi)

            if visibility == 0:
                continue

            lstyle = '-' if (style == 0) else '--'
            axs[0][i].plot(x, y, color=rgb, linewidth=thickness, linestyle=lstyle)
        
        maxKeyLen = max([len(key) for key in meta.keys()])
        print("MetaAttributes:")
        for key, value in meta.items():
            print(f'  {key:{maxKeyLen}} : {value}')

    # Adjust layout to prevent clipping of titles
    plt.tight_layout(pad=0.5)

    plt.show()
# Out:
# File data/recon.mrd contains 31 groups (reconstruction runs):
#   2026-06-01 09:33:32.828918
#   2026-06-01 10:00:22.787041
#   2026-06-01 10:00:42.952301
#   2026-06-01 10:42:58.577762
#   2026-06-01 10:45:18.122040
#   2026-06-01 10:47:37.430498
#   2026-06-01 10:48:20.326888
#   2026-06-01 10:55:01.929994
#   2026-06-01 10:55:23.106971
#   2026-06-01 11:01:59.343331
#   2026-06-01 11:02:22.481313
#   2026-06-01 11:08:12.967541
#   2026-06-03 08:47:51.276796
#   2026-06-10 12:04:34.153889
#   2026-06-10 13:30:28.642786
#   2026-06-18 11:29:37.325057
#   2026-06-18 11:30:57.045951
#   2026-06-18 11:32:07.217002
#   2026-06-18 12:57:21.223093
#   2026-06-18 13:03:38.369658
#   2026-06-29 11:48:45.085287
#   2026-06-29 11:49:40.780163
#   2026-06-29 11:50:25.959546
#   2026-06-29 11:51:25.551268
#   2026-06-29 11:52:57.121881
#   2026-06-29 11:54:57.369100
#   2026-06-29 11:57:32.197499
#   2026-06-29 11:59:50.198185
#   2026-06-29 12:09:36.846528
#   2026-06-29 12:10:30.551481
#   2026-06-29 12:13:00.488793
# Group 2026-06-29 12:13:00.488793 contains 2 image series:
#   image_0 (2 images)
#   image_99 (280 images)
# MetaAttributes:
#   ImageType                     : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription           : trufi_lung
#   DicomJson                     : ...
#   DataRole                      : Image
#   ImageProcessingHistory        : ['PYTHON', 'INVERT']
#   WindowCenter                  : 2048.0
#   WindowWidth                   : 4096
#   SequenceDescriptionAdditional : FIRE
#   Keep_image_geometry           : 1
#   ImageRowDir                   : ['1.000000000000000000', '0.000000000000000000', '0.000000000000000000']
#   ImageColumnDir                : ['0.000000000000000000', '0.000000000000000000', '-1.000000000000000000']
# MetaAttributes:
#   ImageType           : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription : trufi_lung
#   DicomJson           : ...
#   Keep_image_geometry : 1
# /usr/local/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
