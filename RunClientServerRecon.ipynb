# %% [markdown]
# # Create/convert an input dataset in MRD format
#
# Prepare a dataset in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html) by converting acquired data or by generating a synthetic phantom dataset.  Raw k-space data can be converted using tools such as [siemens_to_ismrmrd](https://github.com/ismrmrd/siemens_to_ismrmrd), [ge_to_ismrmrd](https://github.com/ismrmrd/ge_to_ismrmrd), [philips_to_ismrmrd](https://github.com/ismrmrd/philips_to_ismrmrd), and [bruker_to_ismrmrd](https://github.com/ismrmrd/bruker_to_ismrmrd), while DICOM image data can be converted to DICOM using [dicom2mrd.py](https://github.com/kspaceKelvin/python-ismrmrd-server#UsingDICOMimagesasinputdata).  The [generate_cartesian_shepp_logan_dataset.py](../generate_cartesian_shepp_logan_dataset.py) script can also be used to generate multi-channel raw k-space data.

# %% [markdown]
# ## Option 1: Simulate a raw k-space dataset of the Shepp-Logan phantom
# **Note** This section requires that the [ismrmrd-python-tools](https://github.com/ismrmrd/ismrmrd-python-tools) repo be installed (see [readme.md](../readme.md#Settingupacondaenvironment))

# %%
# Generate a raw k-space dataset of the Shepp-Logan phantom
import os
import generate_cartesian_shepp_logan_dataset

inputFilename = 'data/raw.mrd'

dir, file = os.path.split(inputFilename)
if dir and not os.path.exists(dir):
    print(f'Creating parent directory {dir}')
    os.makedirs(dir)

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

generate_cartesian_shepp_logan_dataset.create(filename=inputFilename, matrix_size=256, coils=8, oversampling=2, repetitions=1, acceleration=1, noise_level=0.05)
# Out:
# Creating Shepp-Logan phantom raw data:
# Matrix 256x256 at R=1 with 1 repetitions
# 8 coils with 2 oversampling and 0.05 noise level
# Saved to data/raw.mrd

# %% [markdown]
# ## Option 2: Convert raw k-space data acquired from an MRI scanner

# %%
# Run siemens_to_ismrmrd to convert a .dat file into MRD format
# Note that as there is no Windows executable, this must be run in Linux or in a devcontainer

# Relative path to Siemens .dat file (note this .ipynb file likely exists in the doc subfolder!)
datFile = 'data/MiniFLASH_Fire.dat'

# Measurement in the multi-RAID .dat file to convert.  Note the .dat file may contain dependent
# scans, e.g. AdjCoilSens and the desired scan is usually the last in the multi-RAID file
# Negative indices are relative to the end (e.g. -1 for the last measurement)
measNum = '-1'

# Parameter map and stylesheet to use to convert from Siemens parameter buffers to an MRD header.
# These can specify a relative path to local files or files embedded inside siemens_to_ismrmrd.
# These arguments can also be omitted and will default to these values.
paramMap      = None
paramMapStyle = None

# The output file can be specified with the "--output" option, but will be named with the same
# filename as the input file (with a .mrd extension) if omitted.

import subprocess
import os

inputFilename = os.path.splitext(datFile)[0] + '.mrd'
if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

command = ['siemens_to_ismrmrd', '--measNum', measNum, '--file', datFile]
if paramMap is not None:
    command.extend(('--pMap', paramMap))

if paramMapStyle is not None:
    command.extend(('--pMapStyle', paramMapStyle))

try:
    result = subprocess.run(command, check=True, text=True, capture_output=True)
    print("Output:", result.stdout)
except subprocess.CalledProcessError as e:
    raise Exception("Error:", e.stderr)
# Out:
# Output: Siemens file is: data/MiniFLASH_Fire.dat
# Output file not specified -- using data/MiniFLASH_Fire.mrd
# -----------------------------------------------------------------
# Converting measurement 1 into file data/MiniFLASH_Fire.mrd in group dataset
# -----------------------------------------------------------------
# Using parameter map: IsmrmrdParameterMap_Siemens.xml
# This file contains 1 measurement(s).
# VD line file detected.
# Protocol name [1]: MiniFLASH_Fire
# Number of parameter buffers: 6
# Buffer Name: Config
# Buffer Name: Dicom
# Buffer Name: Meas
# Buffer Name: MeasYaps
# Buffer Name: Phoenix
# Buffer Name: Spice
# Trajectory is: 1
# Failed to find YAPS.lFirstFourierLine array
# Failed to find YAPS.lFirstFourierPartition array
# center_line = 64
# center_partition = 0
# Baseline: N4_VE11C_LATEST_20160120
# Software version: syngo MR E11
# Protocol name: MiniFLASH_Fire
# Dwell time: 15000
# Using parameter XSL: IsmrmrdParameterMap_Siemens.xsl
# Study time: 16:06:09
# Last scan reached...

# %% [markdown]
# ## Visualize raw k-space data
# Inspect and visualize the raw k-space dataset using the [ismrmrd-python](https://github.com/ismrmrd/ismrmrd-python) library.  Data from multiple scans/acquisitions can be stored in a single file, grouped in ['datasets'](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html#mrd-file-format).  The datasets in a file can be listed with:

# %%
# Display the generated raw k-space data
import h5py
import ismrmrd
import numpy as np
import matplotlib.pyplot as plt

datasetName = 'dataset'

# List all datasets in the file
with h5py.File(inputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File "%s" contains %d datasets:' % (inputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[0]

    datasetName = list(d.keys())[0]

print('Reading dataset "%s" from file "%s"' % (datasetName, inputFilename))
with ismrmrd.Dataset(inputFilename, datasetName, False) as dset:
    # Read MRD header
    xmlHeader = dset.read_xml_header().decode('utf-8')
    mrdHeader = ismrmrd.xsd.CreateFromDocument(xmlHeader)

    # Get all readouts
    acqs = [dset.read_acquisition(idx) for idx in range(dset.number_of_acquisitions())]

    # Limit to imaging (non-noise) readouts
    imgAcqs = [acq for acq in acqs if not acq.is_flag_set(ismrmrd.ACQ_IS_NOISE_MEASUREMENT)]

    print('There are %d imaging readouts out of a total of %d readouts' % (len(imgAcqs), dset.number_of_acquisitions()))

# List index counters that have >1 unique values
idxFields = ['average', 'contrast', 'kspace_encode_step_1', 'kspace_encode_step_2', 'phase', 'repetition', 'segment', 'set', 'slice']
print("Loop index counters with unique values:")
for field in idxFields:
    vals = set([getattr(acq.idx, field) for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  {field:20s} has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

for i in range(8):
    vals = set([acq.idx.user[i] for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  user[{i}]              has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

# Format data into single [cha PE RO rep] array
lin = [acq.idx.kspace_encode_step_1 for acq in imgAcqs]
rep = [acq.idx.repetition           for acq in imgAcqs]

raw = np.zeros((mrdHeader.acquisitionSystemInformation.receiverChannels, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.y, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.x, 
                mrdHeader.encoding[0].encodingLimits.repetition.maximum+1), 
                imgAcqs[0].data.dtype)

for acq, lin, rep in zip(imgAcqs, lin, rep):
    raw[:,lin,-acq.data.shape[1]:,rep] = acq.data

# Show the AcquisitionHeader flags for each line of k-space
print("Readouts with AcquisitionHeader flags present:")
acqFlags = [field for field in dir(ismrmrd) if field.startswith('ACQ_')]
for i, acq in enumerate(imgAcqs):
    strFlags = ", ".join([field for field in acqFlags if acq.is_flag_set(getattr(ismrmrd, field))])
    if strFlags:
        print(f'[{i:3d}] Lin {acq.idx.kspace_encode_step_1}: {strFlags}')

t = np.log(np.abs(raw[0,:,:,0]))
t[np.isinf(t)] = 0

dpi = 100
plt.figure(figsize=(3*t.shape[1] / dpi, 3*t.shape[0] / dpi), dpi=dpi)
plt.imshow(t, interpolation='nearest')
plt.title('Raw k-space (rep %d/%d, coil %d/%d)' % (1, mrdHeader.encoding[0].encodingLimits.repetition.maximum+1, 1, mrdHeader.acquisitionSystemInformation.receiverChannels))
# plt.axis('off')
plt.show()
# Out:
# File "data/MiniFLASH_Fire.mrd" contains 1 datasets:
#   dataset
# Reading dataset "dataset" from file "data/MiniFLASH_Fire.mrd"
# There are 128 imaging readouts out of a total of 128 readouts
# Loop index counters with unique values:
#   kspace_encode_step_1 has 128 unique values (min:   0, max: 127)
# Readouts with AcquisitionHeader flags present:
# [  0] Lin 0: ACQ_FIRST_IN_SLICE
# [127] Lin 127: ACQ_LAST_IN_MEASUREMENT, ACQ_LAST_IN_REPETITION, ACQ_LAST_IN_SLICE

# %% [markdown]
# ## Option 3: Convert a set of DICOMs
# For image processing workflows, it may also be useful to use DICOM images as input data.  These can be converted to MRD format using the [dicom2mrd.py](../dicom2mrd.py) script.  Not that the header information from data converted in this way may differ from data converted from the scanner.

# %%
# Folder containing DICOM files
import os
dicomFolder   = r'C:\Lung_Project\Measurements\CDH_Study\20251018_age10'
inputFilename = 'data/dicoms.mrd'

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

import dicom2mrd
from types import SimpleNamespace

# Adjust the logging configuration otherwise INFO level isn't shown in notebook output
import logging
logging.getLogger().setLevel(logging.INFO)

# Specify client arguments for recon
args = SimpleNamespace(**dicom2mrd.defaults)
args.folder   = dicomFolder
args.outFile  = inputFilename

dicom2mrd.main(args)
# Out:
# Found 1 unique series from 280 files in folder C:\Lung_Project\Measurements\CDH_Study\20251018_age10
# Creating MRD XML header from file C:\Lung_Project\Measurements\CDH_Study\20251018_age10\1.dcm
# <?xml version="1.0" encoding="ascii"?>
# <ismrmrdHeader xmlns="http://www.ismrm.org/ISMRMRD">
#  <studyInformation>
#   <studyDate>2025-10-28</studyDate>
#   <studyTime>09:47:16</studyTime>
#   <studyID>04879831</studyID>
#   <studyDescription>Kinderprotokolle Untersuchung_neu</studyDescription>
#   <studyInstanceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000297</studyInstanceUID>
#   <bodyPartExamined>LUNG</bodyPartExamined>
#  </studyInformation>
#  <measurementInformation>
#   <measurementID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000305</measurementID>
#   <patientPosition>HFS</patientPosition>
#   <protocolName>trufi_lung</protocolName>
#   <frameOfReferenceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000306</frameOfReferenceUID>
#  </measurementInformation>
#  <acquisitionSystemInformation>
#   <systemVendor>Siemens Healthineers</systemVendor>
#   <systemModel>MAGNETOM Aera</systemModel>
#   <systemFieldStrength_T>1.5</systemFieldStrength_T>
#  </acquisitionSystemInformation>
#  <experimentalConditions>
#   <H1resonanceFrequency_Hz>63870000</H1resonanceFrequency_Hz>
#  </experimentalConditions>
#  <encoding>
#   <encodedSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </encodedSpace>
#   <reconSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </reconSpace>
#   <encodingLimits/>
#   <trajectory>cartesian</trajectory>
#   <parallelImaging>
#    <accelerationFactor>
#     <kspace_encoding_step_1>3</kspace_encoding_step_1>
#     <kspace_encoding_step_2>1</kspace_encoding_step_2>
#    </accelerationFactor>
#   </parallelImaging>
#  </encoding>
#  <sequenceParameters>
#   <TR>2.06</TR>
#   <flipAngle_deg>30.0</flipAngle_deg>
#  </sequenceParameters>
#  <userParameters>
#   <userParameterDouble>
#    <name>ReadoutOS</name>
#    <value>2.0</value>
#   </userParameterDouble>
#  </userParameters>
# </ismrmrdHeader>
#
# Series 19 has 280 images with 1 slices and 1 phases
# Creating MRD file data/dicoms.mrd with group dataset

# %% [markdown]
# ## Option 4: Save data using server.py
# For inline integration with an MRI scanner or another data source, the conversion to MRD may be done with vendor-provided software.  In this case, it may be desirable to use MRD server in this repository to save a copy of data that it receives, particularly for development purposes.  The data can then be re-run with [client.py](../client.py).  This can be achieved by starting the server with [main.py](../main.py) with the `-s` (`--savedata`) option and data is stored in `/tmp/share/saved_data` unless overridden by the `-S` (`--savedataFolder`) option.

# %%
inputFilename = 'data/dicoms.mrd'

# %% [markdown]
# # Run reconstruction
# Algorithms/reconstructions are run as modules by the server component, which implements the [MRD streaming protocol](https://ismrmrd.readthedocs.io/en/latest/mrd_streaming_protocol.html).  The server must be started separately and a client sends data to the server for processing.  The server can be started via command line by running `python main.py`.
#
# If using Visual Studio Code, [launch.json](../.vscode/launch.json) includes a debug configuration to run the server and allow for interactive debugging.  Click on the "Run and Debug" tab on the top left, then click the green play button to start the desired config ("Start server"):
#
# ![image-2.png](attachment:image-2.png)
#
# Breakpoints can be set by clicking to the left of the line number in a Python file:
#
# ![image.png](attachment:image.png)
#
# After the server is started, begin the reconstruction by running [client.py](../client.py) on the input dataset.  The recon code/module is selected by using the `config` argument.  The output is stored in a separate MRD file under a dataset named with the current date/time.

# %%
# Import the MRD client to send data to server for reconstruction
import client
from types import SimpleNamespace

# Adjust the logging configuration, otherwise INFO level isn't shown in notebook output by default
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

import datetime
outputFilename = 'data/recon.mrd'

# Specify client arguments for recon
args = SimpleNamespace(**client.defaults)
args.config    = 'custom.MAIN_VQMap'  # Recon module to be used
args.port      = 9020
args.out_group = str(datetime.datetime.now())  # Set when using in notebook, otherwise out_group is time of first import of client module
args.outfile   = outputFilename
args.filename  = inputFilename

client.main(args)
# Out:
# 2026-05-26 09:46:59,451 - File data/dicoms.mrd contains 1 groups:
# 2026-05-26 09:46:59,452 - dataset
# 2026-05-26 09:46:59,453 - Reading data from group 'dataset' in file 'data/dicoms.mrd'
# 2026-05-26 09:46:59,456 - Connecting to MRD server at localhost:9020
# No logfile provided
# 2026-05-26 09:46:59,460 - Sending remote config file name 'custom.MAIN_VQMap'
# 2026-05-26 09:46:59,463 - --> Sending MRD_MESSAGE_CONFIG_FILE (1)
# 2026-05-26 09:46:59,471 - --> Sending MRD_MESSAGE_METADATA_XML_TEXT (3)
# 2026-05-26 09:46:59,472 - Starting image data session
# 2026-05-26 09:46:59,473 - Reading images from '/dataset/image_0'
# 2026-05-26 09:46:59,484 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,493 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,501 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,508 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,515 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,522 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,528 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,536 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,887 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,892 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,898 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,905 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,910 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,919 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,924 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,929 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,935 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,941 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,946 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,953 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,957 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,962 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,968 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,973 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,978 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,984 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,989 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:46:59,994 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,000 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,005 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,010 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,022 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,042 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,049 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,054 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,063 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,070 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,075 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,082 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,088 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,095 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,102 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,108 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,116 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,122 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,129 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,136 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,142 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,148 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,155 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,164 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,177 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,187 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,196 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,203 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,211 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,219 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,226 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,234 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,240 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,248 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,254 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,260 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,267 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,273 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,279 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,286 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,291 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,299 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,304 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,310 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,316 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,322 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,329 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,334 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,340 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,346 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,351 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,355 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,360 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,366 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,370 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,375 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,381 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,386 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,391 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,397 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,403 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,407 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,413 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,418 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,422 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,427 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,432 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,437 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,442 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,448 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,453 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,459 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,464 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,470 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,475 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,480 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,486 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,491 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,498 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,503 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,508 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,513 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,519 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,523 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,530 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,535 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,540 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,546 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,551 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,556 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,562 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,569 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,574 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,581 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,586 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,591 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,597 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,602 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,607 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,613 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,619 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,623 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,629 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,634 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,639 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,644 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,649 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,654 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,659 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,665 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,670 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,674 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,681 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,685 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,690 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,696 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,701 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,705 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,711 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,716 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,721 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,726 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,733 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,738 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,743 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,748 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,753 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,758 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,764 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,769 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,773 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,779 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,784 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,789 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,794 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,799 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,804 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,808 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,814 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,818 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,823 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,828 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,833 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,838 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,843 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,856 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,864 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,870 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,875 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,883 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,891 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,903 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,910 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,921 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,926 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,934 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,940 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,945 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,951 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,957 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,963 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,968 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,973 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,978 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,983 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,988 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,993 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:00,998 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,003 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,008 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,014 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,018 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,023 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,029 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,034 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,040 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,046 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,051 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,055 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,062 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,067 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,071 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,076 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,082 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,087 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,093 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,098 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,103 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,108 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,114 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,119 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,124 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,129 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,134 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,139 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,144 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,150 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,155 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,160 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,166 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,170 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,176 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,181 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,186 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,192 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,197 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,202 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,207 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,214 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,218 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,223 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,229 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,233 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,238 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,257 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,262 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,267 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,273 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,278 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,284 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,288 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,293 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,299 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,304 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,309 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,316 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,320 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,325 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,330 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,337 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,342 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,348 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,353 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,358 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,365 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,381 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,387 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,393 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,401 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,407 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,417 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,425 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,432 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,438 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,446 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,452 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,458 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,466 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,472 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,480 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,487 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,493 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,500 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-26 09:47:01,502 - --> Sending MRD_MESSAGE_CLOSE (4)
# 2026-05-26 09:48:11,054 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,057 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,058 - Incoming data will be saved to: 'data/recon.mrd' in group '2026-05-26 09:46:59.448153'
# 2026-05-26 09:48:11,067 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,068 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,075 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,077 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,082 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,083 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,088 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,089 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,095 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,096 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,101 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,102 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,107 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,108 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,113 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,114 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,127 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,128 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,132 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,133 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,137 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,138 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,143 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,144 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,149 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,150 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,154 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,155 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,160 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,161 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,165 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,166 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,179 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,180 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,184 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,185 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,189 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,190 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,195 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,196 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,200 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,201 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,206 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,207 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,211 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,212 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,216 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,217 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,231 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,232 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,238 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,239 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,244 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,245 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,250 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,251 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,256 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,257 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,264 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,265 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,270 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,271 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,276 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,277 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,291 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,292 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,297 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,298 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,302 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,303 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,308 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,309 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,315 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,316 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,320 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,322 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,326 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,328 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,333 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,334 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,347 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,348 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,352 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,353 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,358 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,359 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,365 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,366 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,370 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,371 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,376 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,377 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,382 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,383 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,389 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,390 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,402 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,403 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,408 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,409 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,414 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,415 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,420 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,421 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,426 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,427 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,432 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,433 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,437 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,439 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,443 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,445 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,457 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,459 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,463 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,464 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,468 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,469 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,475 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,476 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,481 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,482 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,486 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,487 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,492 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,493 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,499 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,500 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,515 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,516 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,524 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,525 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,537 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,538 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,543 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,545 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,549 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,550 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,555 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,557 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,561 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,562 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,567 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,569 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,582 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,583 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,588 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,589 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,594 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,595 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,600 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,601 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,606 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,607 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,621 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,623 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,633 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,635 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,643 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,645 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,662 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,664 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,669 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,670 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,676 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,678 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,683 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,684 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,689 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,690 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,695 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,696 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,701 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,702 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,709 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,710 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,724 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,725 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,731 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,732 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,737 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,738 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,743 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,744 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,749 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,750 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,755 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,757 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,761 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,763 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,767 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,768 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,781 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,782 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,787 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,788 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,792 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,793 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,798 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,799 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,803 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,804 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,809 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,810 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,814 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,816 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,820 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,822 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,835 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,836 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,840 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,841 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,845 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,846 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,851 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,852 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,857 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,858 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,862 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,863 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,867 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,868 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,873 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,874 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,886 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,888 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,892 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,894 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,898 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,899 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,903 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,904 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,911 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,912 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,916 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,917 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,922 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,923 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,928 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,929 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,942 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,943 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,948 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,949 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,953 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,954 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,959 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,960 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,964 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,965 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,970 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,973 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,978 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,979 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,983 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,984 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:11,998 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:11,999 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,003 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,004 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,009 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,010 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,014 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,015 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,020 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,021 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,026 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,027 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,031 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,032 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,037 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,038 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,051 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,052 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,056 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,058 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,062 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,063 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,067 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,068 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,073 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,074 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,078 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,079 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,083 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,084 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,089 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,090 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,102 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,103 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,108 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,109 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,114 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,115 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,121 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,122 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,126 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,128 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,133 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# ...
# 2026-05-26 09:48:12,442 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,443 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,448 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,449 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,453 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,454 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,459 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,460 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,464 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,465 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,478 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,479 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,483 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,484 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,489 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,490 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,494 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,495 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,499 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,500 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,506 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,507 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,512 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,513 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,517 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,518 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,531 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,532 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,536 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,537 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,541 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,542 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,547 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,548 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,552 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,553 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,557 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,559 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,563 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,564 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,568 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,569 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,582 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,583 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,588 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,589 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,593 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,594 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,599 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,600 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,604 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,605 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,610 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,611 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,616 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,617 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,623 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,625 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,639 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,641 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,647 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,648 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,652 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,653 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,658 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,659 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,663 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,664 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,669 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,671 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,676 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,677 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,682 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,683 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,699 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,700 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,705 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,707 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,711 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,712 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,717 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,718 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,723 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,724 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,729 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,730 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,735 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,736 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,741 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,743 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,756 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,757 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,762 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,763 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,767 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,768 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,773 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,774 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,779 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,780 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,784 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,785 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,790 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,791 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,796 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,797 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,811 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,812 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,817 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,817 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,822 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,824 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,828 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,829 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,833 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,834 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,839 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,841 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,845 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,846 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,851 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,852 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,864 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,866 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,870 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,871 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,875 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,876 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,881 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,882 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,886 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,887 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,892 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,893 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,897 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,898 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,902 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,903 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,916 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,917 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,922 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,923 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,927 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,928 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,933 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,934 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,939 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,940 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,944 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,945 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,949 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,950 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,956 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,957 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,969 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,971 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,976 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,977 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,982 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,983 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,989 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,990 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:12,994 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:12,995 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,000 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,001 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,006 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,007 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,012 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,013 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,026 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,027 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,031 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,032 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,036 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,037 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,042 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,043 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,047 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,048 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,052 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,053 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,058 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,059 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,064 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,065 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,081 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-26 09:48:13,082 -     Image is size 256 x 256 x 1 with 1 channels of type uint16
# 2026-05-26 09:48:13,087 - <-- Received MRD_MESSAGE_CLOSE (4)
# 2026-05-26 09:48:13,087 -     Total received acquisitions:     0
# 2026-05-26 09:48:13,088 -     Total received images:         282
# 2026-05-26 09:48:13,089 -     Total received waveforms:        0
# 2026-05-26 09:48:13,089 - ------------------------------------------
# 2026-05-26 09:48:13,095 - Socket closed (writer)
# 2026-05-26 09:48:13,102 - ---------------------- Summary ----------------------
# 2026-05-26 09:48:13,102 - Sent     0 acquisitions  |  Received     0 acquisitions
# 2026-05-26 09:48:13,103 - Sent   280 images        |  Received   282 images
# 2026-05-26 09:48:13,103 - Sent     0 waveforms     |  Received     0 waveforms
# 2026-05-26 09:48:13,104 - Results written to data/recon.mrd
# 2026-05-26 09:48:13,104 - Session complete

# %% [markdown]
# # Display the reconstructed/processed images
# The output is an [HDF5-formatted file](https://www.hdfgroup.org/downloads/hdfview/) that is organized in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html).  It can be opened using MRD toolboxes for [python](https://github.com/ismrmrd/ismrmrd-python) or [MATLAB](https://github.com/ismrmrd/ismrmrd/tree/master/matlab/%2Bismrmrd) or the [ismrmrdviewer](https://github.com/ismrmrd/ismrmrdviewer).  The client can be run multiple times with the same output file and results are grouped by dataset.

# %%
# Display the reconstructed images
import h5py
import ismrmrd
import mrdhelper
import numpy as np
import matplotlib.pyplot as plt
import re

# Uncomment to display images from a different output file
outputFilename = 'data/recon.mrd'

# If run multiple times, the recon.mrd file will have multiple reconstructed images
# Find the most recent recon run
with h5py.File(outputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File %s contains %d groups (reconstruction runs):' % (outputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[-1]

with ismrmrd.Dataset(outputFilename, group, False) as dset:
    subgroups = dset.list()

    # Images are organized by series number in subgroups that start with 'image_' or 'images_'
    imgGroups = [group for group in list(subgroups) if (group.find('image_') != -1) or (group.find('images_') != -1)]
    imgGroupsWithNumImages = [f'{group} ({dset.number_of_images(group)} image{"s"[:dset.number_of_images(group)^1]})' for group in imgGroups]
    print('Group %s contains %d image series:' % (group, len(imgGroups)))
    print(' ', '\n  '.join(imgGroupsWithNumImages))

    # Show images
    fig, axs = plt.subplots(nrows=1, ncols=len(imgGroups), squeeze=False, figsize=(10,5))

    for i, series in enumerate(imgGroups):
        n = dset.number_of_images(series)
        img = dset.read_image(series, 0)
        meta = ismrmrd.Meta.deserialize(img.attribute_string)

        seriesNumber = re.search(r'(?<=_)\d+$', series).group(0)
        title = f'Series {re.search(r'(?<=_)\d+$', series).group(0)}, Image 1/{n}'
        if 'ImageComments' in meta.keys():
            title += '\n' + meta['ImageComments']

        axs[0][i].imshow(np.squeeze(img.data), cmap='gray')
        axs[0][i].set_title(title)
        axs[0][i].axis('off')
        axs[0][i].set_aspect('equal')

        # Read and plot ROIs
        for key in meta.keys():
            if not key.startswith('ROI_'):
                continue

            roi = meta[key]
            x, y, rgb, thickness, style, visibility = mrdhelper.parse_roi(roi)

            if visibility == 0:
                continue

            lstyle = '-' if (style == 0) else '--'
            axs[0][i].plot(x, y, color=rgb, linewidth=thickness, linestyle=lstyle)
        
        maxKeyLen = max([len(key) for key in meta.keys()])
        print("MetaAttributes:")
        for key, value in meta.items():
            print(f'  {key:{maxKeyLen}} : {value}')

    # Adjust layout to prevent clipping of titles
    plt.tight_layout(pad=0.5)

    plt.show()
# Out:
# File data/recon.mrd contains 11 groups (reconstruction runs):
#   2026-05-20 11:37:04.996605
#   2026-05-20 11:40:43.435208
#   2026-05-20 11:41:33.930310
#   2026-05-20 11:47:38.941154
#   2026-05-20 11:57:39.407014
#   2026-05-20 11:58:28.853187
#   2026-05-20 12:13:00.200305
#   2026-05-20 13:00:18.938511
#   2026-05-20 13:04:31.928644
#   2026-05-20 13:09:15.975190
#   2026-05-21 06:24:47.192308
# Group 2026-05-21 06:24:47.192308 contains 2 image series:
#   image_0 (2 images)
#   image_99 (280 images)
# MetaAttributes:
#   ImageType                     : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription           : trufi_lung
#   DicomJson                     : ...
#   DataRole                      : Image
#   ImageProcessingHistory        : ['PYTHON', 'INVERT']
#   WindowCenter                  : 2048.0
#   WindowWidth                   : 4096
#   SequenceDescriptionAdditional : FIRE
#   Keep_image_geometry           : 1
#   ImageRowDir                   : ['1.000000000000000000', '-0.000143149998621084', '0.000000000000083000']
#   ImageColumnDir                : ['0.000006547859811690', '0.045741301029920578', '-0.998952984809875488']
# MetaAttributes:
#   ImageType           : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription : trufi_lung
#   DicomJson           : ...
#   Keep_image_geometry : 1
# /usr/local/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
