# %% [markdown]
# # Create/convert an input dataset in MRD format
#
# Prepare a dataset in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html) by converting acquired data or by generating a synthetic phantom dataset.  Raw k-space data can be converted using tools such as [siemens_to_ismrmrd](https://github.com/ismrmrd/siemens_to_ismrmrd), [ge_to_ismrmrd](https://github.com/ismrmrd/ge_to_ismrmrd), [philips_to_ismrmrd](https://github.com/ismrmrd/philips_to_ismrmrd), and [bruker_to_ismrmrd](https://github.com/ismrmrd/bruker_to_ismrmrd), while DICOM image data can be converted to DICOM using [dicom2mrd.py](https://github.com/kspaceKelvin/python-ismrmrd-server#UsingDICOMimagesasinputdata).  The [generate_cartesian_shepp_logan_dataset.py](../generate_cartesian_shepp_logan_dataset.py) script can also be used to generate multi-channel raw k-space data.

# %% [markdown]
# ## Option 1: Simulate a raw k-space dataset of the Shepp-Logan phantom
# **Note** This section requires that the [ismrmrd-python-tools](https://github.com/ismrmrd/ismrmrd-python-tools) repo be installed (see [readme.md](../readme.md#Settingupacondaenvironment))

# %%
# Generate a raw k-space dataset of the Shepp-Logan phantom
import os
import generate_cartesian_shepp_logan_dataset

inputFilename = 'data/raw.mrd'

dir, file = os.path.split(inputFilename)
if dir and not os.path.exists(dir):
    print(f'Creating parent directory {dir}')
    os.makedirs(dir)

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

generate_cartesian_shepp_logan_dataset.create(filename=inputFilename, matrix_size=256, coils=8, oversampling=2, repetitions=1, acceleration=1, noise_level=0.05)
# Out:
# Creating Shepp-Logan phantom raw data:
# Matrix 256x256 at R=1 with 1 repetitions
# 8 coils with 2 oversampling and 0.05 noise level
# Saved to data/raw.mrd

# %% [markdown]
# ## Option 2: Convert raw k-space data acquired from an MRI scanner

# %%
# Run siemens_to_ismrmrd to convert a .dat file into MRD format
# Note that as there is no Windows executable, this must be run in Linux or in a devcontainer

# Relative path to Siemens .dat file (note this .ipynb file likely exists in the doc subfolder!)
datFile = 'data/MiniFLASH_Fire.dat'

# Measurement in the multi-RAID .dat file to convert.  Note the .dat file may contain dependent
# scans, e.g. AdjCoilSens and the desired scan is usually the last in the multi-RAID file
# Negative indices are relative to the end (e.g. -1 for the last measurement)
measNum = '-1'

# Parameter map and stylesheet to use to convert from Siemens parameter buffers to an MRD header.
# These can specify a relative path to local files or files embedded inside siemens_to_ismrmrd.
# These arguments can also be omitted and will default to these values.
paramMap      = None
paramMapStyle = None

# The output file can be specified with the "--output" option, but will be named with the same
# filename as the input file (with a .mrd extension) if omitted.

import subprocess
import os

inputFilename = os.path.splitext(datFile)[0] + '.mrd'
if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

command = ['siemens_to_ismrmrd', '--measNum', measNum, '--file', datFile]
if paramMap is not None:
    command.extend(('--pMap', paramMap))

if paramMapStyle is not None:
    command.extend(('--pMapStyle', paramMapStyle))

try:
    result = subprocess.run(command, check=True, text=True, capture_output=True)
    print("Output:", result.stdout)
except subprocess.CalledProcessError as e:
    raise Exception("Error:", e.stderr)
# Out:
# Output: Siemens file is: data/MiniFLASH_Fire.dat
# Output file not specified -- using data/MiniFLASH_Fire.mrd
# -----------------------------------------------------------------
# Converting measurement 1 into file data/MiniFLASH_Fire.mrd in group dataset
# -----------------------------------------------------------------
# Using parameter map: IsmrmrdParameterMap_Siemens.xml
# This file contains 1 measurement(s).
# VD line file detected.
# Protocol name [1]: MiniFLASH_Fire
# Number of parameter buffers: 6
# Buffer Name: Config
# Buffer Name: Dicom
# Buffer Name: Meas
# Buffer Name: MeasYaps
# Buffer Name: Phoenix
# Buffer Name: Spice
# Trajectory is: 1
# Failed to find YAPS.lFirstFourierLine array
# Failed to find YAPS.lFirstFourierPartition array
# center_line = 64
# center_partition = 0
# Baseline: N4_VE11C_LATEST_20160120
# Software version: syngo MR E11
# Protocol name: MiniFLASH_Fire
# Dwell time: 15000
# Using parameter XSL: IsmrmrdParameterMap_Siemens.xsl
# Study time: 16:06:09
# Last scan reached...

# %% [markdown]
# ## Visualize raw k-space data
# Inspect and visualize the raw k-space dataset using the [ismrmrd-python](https://github.com/ismrmrd/ismrmrd-python) library.  Data from multiple scans/acquisitions can be stored in a single file, grouped in ['datasets'](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html#mrd-file-format).  The datasets in a file can be listed with:

# %%
# Display the generated raw k-space data
import h5py
import ismrmrd
import numpy as np
import matplotlib.pyplot as plt

datasetName = 'dataset'

# List all datasets in the file
with h5py.File(inputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File "%s" contains %d datasets:' % (inputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[0]

    datasetName = list(d.keys())[0]

print('Reading dataset "%s" from file "%s"' % (datasetName, inputFilename))
with ismrmrd.Dataset(inputFilename, datasetName, False) as dset:
    # Read MRD header
    xmlHeader = dset.read_xml_header().decode('utf-8')
    mrdHeader = ismrmrd.xsd.CreateFromDocument(xmlHeader)

    # Get all readouts
    acqs = [dset.read_acquisition(idx) for idx in range(dset.number_of_acquisitions())]

    # Limit to imaging (non-noise) readouts
    imgAcqs = [acq for acq in acqs if not acq.is_flag_set(ismrmrd.ACQ_IS_NOISE_MEASUREMENT)]

    print('There are %d imaging readouts out of a total of %d readouts' % (len(imgAcqs), dset.number_of_acquisitions()))

# List index counters that have >1 unique values
idxFields = ['average', 'contrast', 'kspace_encode_step_1', 'kspace_encode_step_2', 'phase', 'repetition', 'segment', 'set', 'slice']
print("Loop index counters with unique values:")
for field in idxFields:
    vals = set([getattr(acq.idx, field) for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  {field:20s} has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

for i in range(8):
    vals = set([acq.idx.user[i] for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  user[{i}]              has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

# Format data into single [cha PE RO rep] array
lin = [acq.idx.kspace_encode_step_1 for acq in imgAcqs]
rep = [acq.idx.repetition           for acq in imgAcqs]

raw = np.zeros((mrdHeader.acquisitionSystemInformation.receiverChannels, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.y, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.x, 
                mrdHeader.encoding[0].encodingLimits.repetition.maximum+1), 
                imgAcqs[0].data.dtype)

for acq, lin, rep in zip(imgAcqs, lin, rep):
    raw[:,lin,-acq.data.shape[1]:,rep] = acq.data

# Show the AcquisitionHeader flags for each line of k-space
print("Readouts with AcquisitionHeader flags present:")
acqFlags = [field for field in dir(ismrmrd) if field.startswith('ACQ_')]
for i, acq in enumerate(imgAcqs):
    strFlags = ", ".join([field for field in acqFlags if acq.is_flag_set(getattr(ismrmrd, field))])
    if strFlags:
        print(f'[{i:3d}] Lin {acq.idx.kspace_encode_step_1}: {strFlags}')

t = np.log(np.abs(raw[0,:,:,0]))
t[np.isinf(t)] = 0

dpi = 100
plt.figure(figsize=(3*t.shape[1] / dpi, 3*t.shape[0] / dpi), dpi=dpi)
plt.imshow(t, interpolation='nearest')
plt.title('Raw k-space (rep %d/%d, coil %d/%d)' % (1, mrdHeader.encoding[0].encodingLimits.repetition.maximum+1, 1, mrdHeader.acquisitionSystemInformation.receiverChannels))
# plt.axis('off')
plt.show()
# Out:
# File "data/MiniFLASH_Fire.mrd" contains 1 datasets:
#   dataset
# Reading dataset "dataset" from file "data/MiniFLASH_Fire.mrd"
# There are 128 imaging readouts out of a total of 128 readouts
# Loop index counters with unique values:
#   kspace_encode_step_1 has 128 unique values (min:   0, max: 127)
# Readouts with AcquisitionHeader flags present:
# [  0] Lin 0: ACQ_FIRST_IN_SLICE
# [127] Lin 127: ACQ_LAST_IN_MEASUREMENT, ACQ_LAST_IN_REPETITION, ACQ_LAST_IN_SLICE

# %% [markdown]
# ## Option 3: Convert a set of DICOMs
# For image processing workflows, it may also be useful to use DICOM images as input data.  These can be converted to MRD format using the [dicom2mrd.py](../dicom2mrd.py) script.  Not that the header information from data converted in this way may differ from data converted from the scanner.

# %%
# Folder containing DICOM files
import os
dicomFolder   = r'C:\Lung_Project\Measurements\CDH_Study\20251018_age10'
inputFilename = 'data/dicoms.mrd'

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

import dicom2mrd
from types import SimpleNamespace

# Adjust the logging configuration otherwise INFO level isn't shown in notebook output
import logging
logging.getLogger().setLevel(logging.INFO)

# Specify client arguments for recon
args = SimpleNamespace(**dicom2mrd.defaults)
args.folder   = dicomFolder
args.outFile  = inputFilename

dicom2mrd.main(args)
# Out:
# Found 1 unique series from 280 files in folder C:\Lung_Project\Measurements\CDH_Study\20251018_age10
# Creating MRD XML header from file C:\Lung_Project\Measurements\CDH_Study\20251018_age10\1.dcm
# <?xml version="1.0" encoding="ascii"?>
# <ismrmrdHeader xmlns="http://www.ismrm.org/ISMRMRD">
#  <studyInformation>
#   <studyDate>2025-10-28</studyDate>
#   <studyTime>09:47:16</studyTime>
#   <studyID>04879831</studyID>
#   <studyDescription>Kinderprotokolle Untersuchung_neu</studyDescription>
#   <studyInstanceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000297</studyInstanceUID>
#   <bodyPartExamined>LUNG</bodyPartExamined>
#  </studyInformation>
#  <measurementInformation>
#   <measurementID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000305</measurementID>
#   <patientPosition>HFS</patientPosition>
#   <protocolName>trufi_lung</protocolName>
#   <frameOfReferenceUID>1.3.12.2.1107.5.2.18.141978.30000025111012054229800000306</frameOfReferenceUID>
#  </measurementInformation>
#  <acquisitionSystemInformation>
#   <systemVendor>Siemens Healthineers</systemVendor>
#   <systemModel>MAGNETOM Aera</systemModel>
#   <systemFieldStrength_T>1.5</systemFieldStrength_T>
#  </acquisitionSystemInformation>
#  <experimentalConditions>
#   <H1resonanceFrequency_Hz>63870000</H1resonanceFrequency_Hz>
#  </experimentalConditions>
#  <encoding>
#   <encodedSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </encodedSpace>
#   <reconSpace>
#    <matrixSize>
#     <x>256</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </reconSpace>
#   <encodingLimits/>
#   <trajectory>cartesian</trajectory>
#   <parallelImaging>
#    <accelerationFactor>
#     <kspace_encoding_step_1>3</kspace_encoding_step_1>
#     <kspace_encoding_step_2>1</kspace_encoding_step_2>
#    </accelerationFactor>
#   </parallelImaging>
#  </encoding>
#  <sequenceParameters>
#   <TR>2.06</TR>
#   <flipAngle_deg>30.0</flipAngle_deg>
#  </sequenceParameters>
#  <userParameters>
#   <userParameterDouble>
#    <name>ReadoutOS</name>
#    <value>2.0</value>
#   </userParameterDouble>
#  </userParameters>
# </ismrmrdHeader>
#
# Series 19 has 280 images with 1 slices and 1 phases
# Creating MRD file data/dicoms.mrd with group dataset

# %% [markdown]
# ## Option 4: Save data using server.py
# For inline integration with an MRI scanner or another data source, the conversion to MRD may be done with vendor-provided software.  In this case, it may be desirable to use MRD server in this repository to save a copy of data that it receives, particularly for development purposes.  The data can then be re-run with [client.py](../client.py).  This can be achieved by starting the server with [main.py](../main.py) with the `-s` (`--savedata`) option and data is stored in `/tmp/share/saved_data` unless overridden by the `-S` (`--savedataFolder`) option.

# %%
inputFilename = 'data/dicoms.mrd'

# %% [markdown]
# # Run reconstruction
# Algorithms/reconstructions are run as modules by the server component, which implements the [MRD streaming protocol](https://ismrmrd.readthedocs.io/en/latest/mrd_streaming_protocol.html).  The server must be started separately and a client sends data to the server for processing.  The server can be started via command line by running `python main.py`.
#
# If using Visual Studio Code, [launch.json](../.vscode/launch.json) includes a debug configuration to run the server and allow for interactive debugging.  Click on the "Run and Debug" tab on the top left, then click the green play button to start the desired config ("Start server"):
#
# ![image-2.png](attachment:image-2.png)
#
# Breakpoints can be set by clicking to the left of the line number in a Python file:
#
# ![image.png](attachment:image.png)
#
# After the server is started, begin the reconstruction by running [client.py](../client.py) on the input dataset.  The recon code/module is selected by using the `config` argument.  The output is stored in a separate MRD file under a dataset named with the current date/time.

# %%
# Import the MRD client to send data to server for reconstruction
import client
from types import SimpleNamespace

# Adjust the logging configuration, otherwise INFO level isn't shown in notebook output by default
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

import datetime
outputFilename = 'data/recon.mrd'

# Specify client arguments for recon
args = SimpleNamespace(**client.defaults)
args.config    = 'custom.filter'  # Recon module to be used
args.port      = 9020
args.out_group = str(datetime.datetime.now())  # Set when using in notebook, otherwise out_group is time of first import of client module
args.outfile   = outputFilename
args.filename  = inputFilename

client.main(args)
# Out:
# 2026-05-20 11:58:28,857 - File data/dicoms.mrd contains 1 groups:
# 2026-05-20 11:58:28,858 - dataset
# 2026-05-20 11:58:28,858 - Reading data from group 'dataset' in file 'data/dicoms.mrd'
# 2026-05-20 11:58:28,860 - Connecting to MRD server at localhost:9020
# No logfile provided
# /usr/local/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=1992) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# 2026-05-20 11:58:28,866 - Sending remote config file name 'custom.filter'
# 2026-05-20 11:58:28,868 - --> Sending MRD_MESSAGE_CONFIG_FILE (1)
# 2026-05-20 11:58:28,877 - --> Sending MRD_MESSAGE_METADATA_XML_TEXT (3)
# 2026-05-20 11:58:28,878 - Starting image data session
# 2026-05-20 11:58:28,879 - Reading images from '/dataset/image_0'
# 2026-05-20 11:58:28,895 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:28,903 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:28,909 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:28,917 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:28,925 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:28,932 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:28,938 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:28,946 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,183 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,188 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,194 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,200 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,205 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,211 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,217 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,222 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,227 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,233 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,238 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,243 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,249 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,254 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,260 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,264 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,269 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,273 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,279 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,284 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,288 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,293 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,298 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,303 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,309 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,314 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,319 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,323 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,329 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,334 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,340 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,346 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,350 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,355 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,361 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,366 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,371 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,377 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,382 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,387 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,392 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,398 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,403 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,408 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,414 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,419 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,423 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,429 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,434 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,439 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,445 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,449 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,454 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,460 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,466 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,470 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,477 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,482 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,486 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,492 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,497 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,502 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,507 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,515 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,521 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,527 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,532 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,538 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,543 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,549 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,554 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,559 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,566 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,571 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,577 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,583 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,588 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,594 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,599 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,604 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,610 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,616 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,620 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,627 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,632 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,636 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,640 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,648 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,653 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,660 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,666 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,671 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,678 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,683 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,689 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,695 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,701 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,706 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,712 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,718 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,723 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,729 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,734 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,739 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,744 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,749 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,754 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,760 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,765 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,769 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,776 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,782 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,786 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,793 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,798 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,803 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,809 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,815 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,820 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,825 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,830 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,835 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,840 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,846 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,851 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,856 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,862 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,868 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,873 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,880 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,886 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,892 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,898 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,904 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,911 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,917 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,923 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,930 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,936 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,944 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,951 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,957 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,966 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,975 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,984 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,992 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:29,999 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,004 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,011 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,017 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,022 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,029 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,035 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,040 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,047 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,053 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,059 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,066 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,071 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,077 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,082 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,088 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,093 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,099 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,103 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,109 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,115 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,120 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,126 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,131 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,136 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,142 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,147 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,152 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,156 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,162 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,166 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,174 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,179 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,184 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,189 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,195 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,200 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,204 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,209 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,216 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,221 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,226 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,231 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,236 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,240 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,246 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,251 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,256 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,261 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,267 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,271 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,277 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,282 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,287 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,292 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,298 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,303 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,308 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,313 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,318 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,324 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,330 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,335 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,341 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,347 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,352 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,356 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,362 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,367 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,372 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,378 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,383 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,387 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,393 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,398 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,403 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,408 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,413 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,418 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,423 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,428 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,434 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,438 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,444 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,448 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,453 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,458 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,463 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,467 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,472 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,477 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,483 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,487 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,492 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,497 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,502 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,507 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,513 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,517 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,522 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,529 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,533 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,538 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,544 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,549 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,553 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,560 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,564 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,569 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,573 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,580 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,585 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,591 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,597 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,602 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,608 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,614 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,619 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,624 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,630 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,635 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,639 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,645 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,650 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,654 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,660 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-05-20 11:58:30,661 - --> Sending MRD_MESSAGE_CLOSE (4)
# 2026-05-20 11:58:31,371 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,373 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,375 - Incoming data will be saved to: 'data/recon.mrd' in group '2026-05-20 11:58:28.853187'
# 2026-05-20 11:58:31,388 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,389 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,394 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,396 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,399 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,401 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,405 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,406 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,411 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,412 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,417 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,418 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,422 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,423 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,428 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,430 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,442 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,444 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,448 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,449 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,453 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,454 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,460 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,461 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,465 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,466 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,470 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,472 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,476 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,477 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,482 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,483 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,497 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,498 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,502 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,503 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,508 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,509 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,514 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,515 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,519 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,520 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,525 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,527 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,531 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,532 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,536 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,537 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,553 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,554 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,559 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,561 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,565 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,566 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,570 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,571 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,576 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,577 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,582 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,583 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,587 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,588 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,592 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,594 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,606 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,607 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,612 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,613 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,617 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,618 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,622 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,623 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,628 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,629 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,633 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,634 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,638 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,639 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,645 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,646 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,659 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,660 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,664 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,665 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,669 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,670 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,676 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,678 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,682 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,683 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,687 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,688 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,693 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,694 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,699 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,700 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,712 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,713 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,718 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,719 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,723 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,724 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,729 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,730 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,734 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,735 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,740 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,742 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,746 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,747 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,752 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,753 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,766 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,768 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,772 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,773 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,777 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,779 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,783 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,784 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,788 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,789 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,795 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,796 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,800 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,801 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,805 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,806 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,819 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,820 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,825 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,826 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,836 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,838 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,846 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,847 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,852 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,854 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,858 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,860 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,865 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,866 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,870 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,871 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,885 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,887 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,891 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,893 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,897 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,898 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,903 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,904 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,908 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,910 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,914 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,916 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,920 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,921 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,926 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,927 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,939 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,941 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,945 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,946 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,950 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,951 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,956 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,957 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,961 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,963 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,968 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,969 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,973 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,974 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,979 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,980 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,993 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,994 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:31,998 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:31,999 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,003 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,004 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,010 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,011 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,015 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,016 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,021 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,022 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,026 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,028 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,032 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,033 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,046 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,047 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,051 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,052 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,055 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,056 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,061 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,062 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,066 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,067 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,071 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,072 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,077 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,078 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,083 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,084 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,097 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,098 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,103 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,104 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,108 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,109 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,114 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,115 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,119 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,120 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,124 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,126 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,130 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,131 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,139 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,140 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,153 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,154 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,159 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,160 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,165 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,166 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,170 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,171 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,175 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,177 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,181 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,182 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,186 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,187 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,192 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,194 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,205 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,206 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,212 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,213 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,218 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,219 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,223 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,224 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,229 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,230 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,235 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,236 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,241 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,242 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,247 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,248 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,262 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,263 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,268 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,269 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,272 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,273 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,278 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,280 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,284 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,284 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,289 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,290 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,295 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,296 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,300 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,302 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,314 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,315 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,319 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,320 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,324 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,325 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,330 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,331 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,335 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,336 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,341 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,343 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,347 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,348 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,352 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,353 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,368 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,369 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,376 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,377 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,381 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,382 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,386 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,387 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,392 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,393 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# ...
# 2026-05-20 11:58:32,652 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,653 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,660 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,661 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,667 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,668 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,672 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,673 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,678 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,679 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,684 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,685 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,689 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,691 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,696 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,697 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,711 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,712 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,716 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,718 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,721 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,722 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,727 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,728 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,733 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,734 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,739 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,740 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,744 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,746 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,751 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,752 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,767 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,768 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,772 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,774 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,778 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,779 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,793 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,795 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,804 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,806 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,815 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,816 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,822 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,823 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,829 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,830 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,847 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,848 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,853 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,854 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,859 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,860 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,865 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,866 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,870 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,871 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,876 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,877 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,882 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,883 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,887 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,888 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,900 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,901 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,906 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,907 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,911 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,912 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,917 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,918 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,922 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,923 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,929 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,930 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,934 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,935 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,939 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,940 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,953 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,954 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,958 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,959 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,963 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,964 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,971 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,972 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,978 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,979 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,985 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,986 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:32,998 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:32,999 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,007 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,009 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,026 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,027 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,032 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,033 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,037 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,038 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,046 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,047 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,053 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,054 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,060 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,062 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,066 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,068 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,075 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,076 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,089 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,090 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,095 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,097 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,101 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,102 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,107 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,108 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,113 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,114 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,119 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,120 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,124 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,125 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,135 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,137 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,150 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,151 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,156 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,158 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,162 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,163 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,168 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,169 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,173 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,175 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,180 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,181 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,185 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,186 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,191 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,193 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,205 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,206 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,212 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,213 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,217 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,218 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,222 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,224 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,229 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,230 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,234 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,235 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,239 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,240 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,246 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,247 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,259 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,261 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,265 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,266 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,269 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,270 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,277 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,278 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,292 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,295 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,303 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,305 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,313 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,315 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,321 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,322 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,336 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,338 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,343 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,344 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,348 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,349 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,353 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,355 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,359 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,360 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,365 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,366 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,371 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-05-20 11:58:33,373 -     Image is size 256 x 256 x 1 with 1 channels of type int16
# 2026-05-20 11:58:33,379 - <-- Received MRD_MESSAGE_CLOSE (4)
# 2026-05-20 11:58:33,379 -     Total received acquisitions:     0
# 2026-05-20 11:58:33,380 -     Total received images:         280
# 2026-05-20 11:58:33,381 -     Total received waveforms:        0
# 2026-05-20 11:58:33,381 - ------------------------------------------
# 2026-05-20 11:58:33,393 - Socket closed (writer)
# 2026-05-20 11:58:33,399 - ---------------------- Summary ----------------------
# 2026-05-20 11:58:33,399 - Sent     0 acquisitions  |  Received     0 acquisitions
# 2026-05-20 11:58:33,400 - Sent   280 images        |  Received   280 images
# 2026-05-20 11:58:33,400 - Sent     0 waveforms     |  Received     0 waveforms
# 2026-05-20 11:58:33,401 - Results written to data/recon.mrd
# 2026-05-20 11:58:33,401 - Session complete

# %% [markdown]
# # Display the reconstructed/processed images
# The output is an [HDF5-formatted file](https://www.hdfgroup.org/downloads/hdfview/) that is organized in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html).  It can be opened using MRD toolboxes for [python](https://github.com/ismrmrd/ismrmrd-python) or [MATLAB](https://github.com/ismrmrd/ismrmrd/tree/master/matlab/%2Bismrmrd) or the [ismrmrdviewer](https://github.com/ismrmrd/ismrmrdviewer).  The client can be run multiple times with the same output file and results are grouped by dataset.

# %%
# Display the reconstructed images
import h5py
import ismrmrd
import mrdhelper
import numpy as np
import matplotlib.pyplot as plt
import re

# Uncomment to display images from a different output file
outputFilename = 'data/recon.mrd'

# If run multiple times, the recon.mrd file will have multiple reconstructed images
# Find the most recent recon run
with h5py.File(outputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File %s contains %d groups (reconstruction runs):' % (outputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[-1]

with ismrmrd.Dataset(outputFilename, group, False) as dset:
    subgroups = dset.list()

    # Images are organized by series number in subgroups that start with 'image_' or 'images_'
    imgGroups = [group for group in list(subgroups) if (group.find('image_') != -1) or (group.find('images_') != -1)]
    imgGroupsWithNumImages = [f'{group} ({dset.number_of_images(group)} image{"s"[:dset.number_of_images(group)^1]})' for group in imgGroups]
    print('Group %s contains %d image series:' % (group, len(imgGroups)))
    print(' ', '\n  '.join(imgGroupsWithNumImages))

    # Show images
    fig, axs = plt.subplots(nrows=1, ncols=len(imgGroups), squeeze=False, figsize=(10,5))

    for i, series in enumerate(imgGroups):
        n = dset.number_of_images(series)
        img = dset.read_image(series, 0)
        meta = ismrmrd.Meta.deserialize(img.attribute_string)

        seriesNumber = re.search(r'(?<=_)\d+$', series).group(0)
        title = f'Series {re.search(r'(?<=_)\d+$', series).group(0)}, Image 1/{n}'
        if 'ImageComments' in meta.keys():
            title += '\n' + meta['ImageComments']

        axs[0][i].imshow(np.squeeze(img.data), cmap='gray')
        axs[0][i].set_title(title)
        axs[0][i].axis('off')
        axs[0][i].set_aspect('equal')

        # Read and plot ROIs
        for key in meta.keys():
            if not key.startswith('ROI_'):
                continue

            roi = meta[key]
            x, y, rgb, thickness, style, visibility = mrdhelper.parse_roi(roi)

            if visibility == 0:
                continue

            lstyle = '-' if (style == 0) else '--'
            axs[0][i].plot(x, y, color=rgb, linewidth=thickness, linestyle=lstyle)
        
        maxKeyLen = max([len(key) for key in meta.keys()])
        print("MetaAttributes:")
        for key, value in meta.items():
            print(f'  {key:{maxKeyLen}} : {value}')

    # Adjust layout to prevent clipping of titles
    plt.tight_layout(pad=0.5)

    plt.show()
# Out:
# File data/recon.mrd contains 6 groups (reconstruction runs):
#   2026-05-20 11:37:04.996605
#   2026-05-20 11:40:43.435208
#   2026-05-20 11:41:33.930310
#   2026-05-20 11:47:38.941154
#   2026-05-20 11:57:39.407014
#   2026-05-20 11:58:28.853187
# Group 2026-05-20 11:58:28.853187 contains 1 image series:
#   image_0 (280 images)
# MetaAttributes:
#   ImageType                     : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription           : trufi_lung
#   DicomJson                     : ...
#   DataRole                      : Image
#   ImageProcessingHistory        : ['PYTHON', 'FILT']
#   WindowCenter                  : 2048.0
#   WindowWidth                   : 4096
#   SequenceDescriptionAdditional : FILT
#   Keep_image_geometry           : 1
#   ImageRowDir                   : ['1.000000000000000000', '-0.000143149998621084', '0.000000000000083000']
#   ImageColumnDir                : ['0.000006547859811690', '0.045741301029920578', '-0.998952984809875488']
