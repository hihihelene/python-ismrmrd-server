# %% [markdown]
# # Create/convert an input dataset in MRD format
#
# Prepare a dataset in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html) by converting acquired data or by generating a synthetic phantom dataset.  Raw k-space data can be converted using tools such as [siemens_to_ismrmrd](https://github.com/ismrmrd/siemens_to_ismrmrd), [ge_to_ismrmrd](https://github.com/ismrmrd/ge_to_ismrmrd), [philips_to_ismrmrd](https://github.com/ismrmrd/philips_to_ismrmrd), and [bruker_to_ismrmrd](https://github.com/ismrmrd/bruker_to_ismrmrd), while DICOM image data can be converted to DICOM using [dicom2mrd.py](https://github.com/kspaceKelvin/python-ismrmrd-server#UsingDICOMimagesasinputdata).  The [generate_cartesian_shepp_logan_dataset.py](../generate_cartesian_shepp_logan_dataset.py) script can also be used to generate multi-channel raw k-space data.

# %% [markdown]
# ## Option 1: Simulate a raw k-space dataset of the Shepp-Logan phantom
# **Note** This section requires that the [ismrmrd-python-tools](https://github.com/ismrmrd/ismrmrd-python-tools) repo be installed (see [readme.md](../readme.md#Settingupacondaenvironment))

# %%
# Generate a raw k-space dataset of the Shepp-Logan phantom
import os
import generate_cartesian_shepp_logan_dataset

inputFilename = 'data/raw.mrd'

dir, file = os.path.split(inputFilename)
if dir and not os.path.exists(dir):
    print(f'Creating parent directory {dir}')
    os.makedirs(dir)

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

generate_cartesian_shepp_logan_dataset.create(filename=inputFilename, matrix_size=256, coils=8, oversampling=2, repetitions=1, acceleration=1, noise_level=0.05)
# Out:
# Creating Shepp-Logan phantom raw data:
# Matrix 256x256 at R=1 with 1 repetitions
# 8 coils with 2 oversampling and 0.05 noise level
# Saved to data/raw.mrd

# %% [markdown]
# ## Option 2: Convert raw k-space data acquired from an MRI scanner

# %%
# Run siemens_to_ismrmrd to convert a .dat file into MRD format
# Note that as there is no Windows executable, this must be run in Linux or in a devcontainer

# Relative path to Siemens .dat file (note this .ipynb file likely exists in the doc subfolder!)
datFile = 'data/MiniFLASH_Fire.dat'

# Measurement in the multi-RAID .dat file to convert.  Note the .dat file may contain dependent
# scans, e.g. AdjCoilSens and the desired scan is usually the last in the multi-RAID file
# Negative indices are relative to the end (e.g. -1 for the last measurement)
measNum = '-1'

# Parameter map and stylesheet to use to convert from Siemens parameter buffers to an MRD header.
# These can specify a relative path to local files or files embedded inside siemens_to_ismrmrd.
# These arguments can also be omitted and will default to these values.
paramMap      = None
paramMapStyle = None

# The output file can be specified with the "--output" option, but will be named with the same
# filename as the input file (with a .mrd extension) if omitted.

import subprocess
import os

inputFilename = os.path.splitext(datFile)[0] + '.mrd'
if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

command = ['siemens_to_ismrmrd', '--measNum', measNum, '--file', datFile]
if paramMap is not None:
    command.extend(('--pMap', paramMap))

if paramMapStyle is not None:
    command.extend(('--pMapStyle', paramMapStyle))

try:
    result = subprocess.run(command, check=True, text=True, capture_output=True)
    print("Output:", result.stdout)
except subprocess.CalledProcessError as e:
    raise Exception("Error:", e.stderr)
# Out:
# Output: Siemens file is: data/MiniFLASH_Fire.dat
# Output file not specified -- using data/MiniFLASH_Fire.mrd
# -----------------------------------------------------------------
# Converting measurement 1 into file data/MiniFLASH_Fire.mrd in group dataset
# -----------------------------------------------------------------
# Using parameter map: IsmrmrdParameterMap_Siemens.xml
# This file contains 1 measurement(s).
# VD line file detected.
# Protocol name [1]: MiniFLASH_Fire
# Number of parameter buffers: 6
# Buffer Name: Config
# Buffer Name: Dicom
# Buffer Name: Meas
# Buffer Name: MeasYaps
# Buffer Name: Phoenix
# Buffer Name: Spice
# Trajectory is: 1
# Failed to find YAPS.lFirstFourierLine array
# Failed to find YAPS.lFirstFourierPartition array
# center_line = 64
# center_partition = 0
# Baseline: N4_VE11C_LATEST_20160120
# Software version: syngo MR E11
# Protocol name: MiniFLASH_Fire
# Dwell time: 15000
# Using parameter XSL: IsmrmrdParameterMap_Siemens.xsl
# Study time: 16:06:09
# Last scan reached...

# %% [markdown]
# ## Visualize raw k-space data
# Inspect and visualize the raw k-space dataset using the [ismrmrd-python](https://github.com/ismrmrd/ismrmrd-python) library.  Data from multiple scans/acquisitions can be stored in a single file, grouped in ['datasets'](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html#mrd-file-format).  The datasets in a file can be listed with:

# %%
# Display the generated raw k-space data
import h5py
import ismrmrd
import numpy as np
import matplotlib.pyplot as plt

datasetName = 'dataset'

# List all datasets in the file
with h5py.File(inputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File "%s" contains %d datasets:' % (inputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[0]

    datasetName = list(d.keys())[0]

print('Reading dataset "%s" from file "%s"' % (datasetName, inputFilename))
with ismrmrd.Dataset(inputFilename, datasetName, False) as dset:
    # Read MRD header
    xmlHeader = dset.read_xml_header().decode('utf-8')
    mrdHeader = ismrmrd.xsd.CreateFromDocument(xmlHeader)

    # Get all readouts
    acqs = [dset.read_acquisition(idx) for idx in range(dset.number_of_acquisitions())]

    # Limit to imaging (non-noise) readouts
    imgAcqs = [acq for acq in acqs if not acq.is_flag_set(ismrmrd.ACQ_IS_NOISE_MEASUREMENT)]

    print('There are %d imaging readouts out of a total of %d readouts' % (len(imgAcqs), dset.number_of_acquisitions()))

# List index counters that have >1 unique values
idxFields = ['average', 'contrast', 'kspace_encode_step_1', 'kspace_encode_step_2', 'phase', 'repetition', 'segment', 'set', 'slice']
print("Loop index counters with unique values:")
for field in idxFields:
    vals = set([getattr(acq.idx, field) for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  {field:20s} has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

for i in range(8):
    vals = set([acq.idx.user[i] for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  user[{i}]              has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

# Format data into single [cha PE RO rep] array
lin = [acq.idx.kspace_encode_step_1 for acq in imgAcqs]
rep = [acq.idx.repetition           for acq in imgAcqs]

raw = np.zeros((mrdHeader.acquisitionSystemInformation.receiverChannels, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.y, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.x, 
                mrdHeader.encoding[0].encodingLimits.repetition.maximum+1), 
                imgAcqs[0].data.dtype)

for acq, lin, rep in zip(imgAcqs, lin, rep):
    raw[:,lin,-acq.data.shape[1]:,rep] = acq.data

# Show the AcquisitionHeader flags for each line of k-space
print("Readouts with AcquisitionHeader flags present:")
acqFlags = [field for field in dir(ismrmrd) if field.startswith('ACQ_')]
for i, acq in enumerate(imgAcqs):
    strFlags = ", ".join([field for field in acqFlags if acq.is_flag_set(getattr(ismrmrd, field))])
    if strFlags:
        print(f'[{i:3d}] Lin {acq.idx.kspace_encode_step_1}: {strFlags}')

t = np.log(np.abs(raw[0,:,:,0]))
t[np.isinf(t)] = 0

dpi = 100
plt.figure(figsize=(3*t.shape[1] / dpi, 3*t.shape[0] / dpi), dpi=dpi)
plt.imshow(t, interpolation='nearest')
plt.title('Raw k-space (rep %d/%d, coil %d/%d)' % (1, mrdHeader.encoding[0].encodingLimits.repetition.maximum+1, 1, mrdHeader.acquisitionSystemInformation.receiverChannels))
# plt.axis('off')
plt.show()
# Out:
# File "data/MiniFLASH_Fire.mrd" contains 1 datasets:
#   dataset
# Reading dataset "dataset" from file "data/MiniFLASH_Fire.mrd"
# There are 128 imaging readouts out of a total of 128 readouts
# Loop index counters with unique values:
#   kspace_encode_step_1 has 128 unique values (min:   0, max: 127)
# Readouts with AcquisitionHeader flags present:
# [  0] Lin 0: ACQ_FIRST_IN_SLICE
# [127] Lin 127: ACQ_LAST_IN_MEASUREMENT, ACQ_LAST_IN_REPETITION, ACQ_LAST_IN_SLICE

# %% [markdown]
# ## Option 3: Convert a set of DICOMs
# For image processing workflows, it may also be useful to use DICOM images as input data.  These can be converted to MRD format using the [dicom2mrd.py](../dicom2mrd.py) script.  Not that the header information from data converted in this way may differ from data converted from the scanner.

# %%
# Folder containing DICOM files
import os
dicomFolder   = r'C:/Lung_Project/Measurements/CDH_Study/20260217_age10'
inputFilename = 'data/dicoms.mrd'

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

import dicom2mrd
from types import SimpleNamespace

# Adjust the logging configuration otherwise INFO level isn't shown in notebook output
import logging
logging.getLogger().setLevel(logging.INFO)

# Specify client arguments for recon
args = SimpleNamespace(**dicom2mrd.defaults)
args.folder   = dicomFolder
args.outFile  = inputFilename

dicom2mrd.main(args)
# Out:
# Found 1 unique series from 280 files in folder C:/Lung_Project/Measurements/CDH_Study/20260217_age10
# Creating MRD XML header from file C:/Lung_Project/Measurements/CDH_Study/20260217_age10\1.dcm
# <?xml version="1.0" encoding="ascii"?>
# <ismrmrdHeader xmlns="http://www.ismrm.org/ISMRMRD">
#  <studyInformation>
#   <studyDate>2026-02-17</studyDate>
#   <studyTime>10:35:55</studyTime>
#   <studyID>05046715</studyID>
#   <studyDescription>Kinderprotokolle Untersuchung_neu</studyDescription>
#   <studyInstanceUID>1.3.12.2.1107.5.2.18.141978.30000026030214074498000000297</studyInstanceUID>
#   <bodyPartExamined>CHEST</bodyPartExamined>
#  </studyInformation>
#  <measurementInformation>
#   <measurementID>1.3.12.2.1107.5.2.18.141978.30000026030214074498000000305</measurementID>
#   <patientPosition>HFS</patientPosition>
#   <protocolName>trufi_lung</protocolName>
#   <frameOfReferenceUID>1.3.12.2.1107.5.2.18.141978.30000026030214074498000000306</frameOfReferenceUID>
#  </measurementInformation>
#  <acquisitionSystemInformation>
#   <systemVendor>Siemens Healthineers</systemVendor>
#   <systemModel>MAGNETOM Aera</systemModel>
#   <systemFieldStrength_T>1.5</systemFieldStrength_T>
#  </acquisitionSystemInformation>
#  <experimentalConditions>
#   <H1resonanceFrequency_Hz>63870000</H1resonanceFrequency_Hz>
#  </experimentalConditions>
#  <encoding>
#   <encodedSpace>
#    <matrixSize>
#     <x>336</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </encodedSpace>
#   <reconSpace>
#    <matrixSize>
#     <x>336</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </reconSpace>
#   <encodingLimits/>
#   <trajectory>cartesian</trajectory>
#   <parallelImaging>
#    <accelerationFactor>
#     <kspace_encoding_step_1>3</kspace_encoding_step_1>
#     <kspace_encoding_step_2>1</kspace_encoding_step_2>
#    </accelerationFactor>
#   </parallelImaging>
#  </encoding>
#  <sequenceParameters>
#   <TR>2.18</TR>
#   <flipAngle_deg>30.0</flipAngle_deg>
#  </sequenceParameters>
#  <userParameters>
#   <userParameterDouble>
#    <name>ReadoutOS</name>
#    <value>2.0</value>
#   </userParameterDouble>
#  </userParameters>
# </ismrmrdHeader>
#
# Series 19 has 280 images with 1 slices and 1 phases
# Creating MRD file data/dicoms.mrd with group dataset

# %% [markdown]
# ## Option 4: Save data using server.py
# For inline integration with an MRI scanner or another data source, the conversion to MRD may be done with vendor-provided software.  In this case, it may be desirable to use MRD server in this repository to save a copy of data that it receives, particularly for development purposes.  The data can then be re-run with [client.py](../client.py).  This can be achieved by starting the server with [main.py](../main.py) with the `-s` (`--savedata`) option and data is stored in `/tmp/share/saved_data` unless overridden by the `-S` (`--savedataFolder`) option.

# %%
inputFilename = 'data/dicoms.mrd'

# %% [markdown]
# # Run reconstruction
# Algorithms/reconstructions are run as modules by the server component, which implements the [MRD streaming protocol](https://ismrmrd.readthedocs.io/en/latest/mrd_streaming_protocol.html).  The server must be started separately and a client sends data to the server for processing.  The server can be started via command line by running `python main.py`.
#
# If using Visual Studio Code, [launch.json](../.vscode/launch.json) includes a debug configuration to run the server and allow for interactive debugging.  Click on the "Run and Debug" tab on the top left, then click the green play button to start the desired config ("Start server"):
#
# ![image-2.png](attachment:image-2.png)
#
# Breakpoints can be set by clicking to the left of the line number in a Python file:
#
# ![image.png](attachment:image.png)
#
# After the server is started, begin the reconstruction by running [client.py](../client.py) on the input dataset.  The recon code/module is selected by using the `config` argument.  The output is stored in a separate MRD file under a dataset named with the current date/time.

# %%
# Import the MRD client to send data to server for reconstruction
import client
from types import SimpleNamespace

# Adjust the logging configuration, otherwise INFO level isn't shown in notebook output by default
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

import datetime
outputFilename = 'data/recon.mrd'

# Specify client arguments for recon
args = SimpleNamespace(**client.defaults)
args.config    = 'custom.MAIN_VQMap'  # Recon module to be used
args.port      = 9020
args.out_group = str(datetime.datetime.now())  # Set when using in notebook, otherwise out_group is time of first import of client module
args.outfile   = outputFilename
args.filename  = inputFilename

client.main(args)
# Out:
# 2026-06-18 13:03:38,377 - File data/dicoms.mrd contains 1 groups:
# 2026-06-18 13:03:38,377 - dataset
# 2026-06-18 13:03:38,378 - Reading data from group 'dataset' in file 'data/dicoms.mrd'
# 2026-06-18 13:03:38,379 - Connecting to MRD server at localhost:9020
# No logfile provided
# /usr/local/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=783) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# 2026-06-18 13:03:38,387 - Sending remote config file name 'custom.MAIN_VQMap'
# 2026-06-18 13:03:38,389 - --> Sending MRD_MESSAGE_CONFIG_FILE (1)
# 2026-06-18 13:03:38,397 - --> Sending MRD_MESSAGE_METADATA_XML_TEXT (3)
# 2026-06-18 13:03:38,398 - Starting image data session
# 2026-06-18 13:03:38,399 - Reading images from '/dataset/image_0'
# 2026-06-18 13:03:38,412 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:38,419 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:38,425 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:38,432 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:38,437 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:38,444 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:38,451 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,136 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,145 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,156 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,161 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,168 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,174 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,179 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,186 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,191 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,198 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,204 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,209 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,215 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,221 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,226 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,231 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,237 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,242 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,247 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,254 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,259 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,264 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,270 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,275 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,280 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,286 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,292 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,296 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,303 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,308 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,313 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,319 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,325 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,330 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,336 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,341 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,346 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,353 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,358 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,363 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,369 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,374 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,379 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,385 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,392 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,398 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,404 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,409 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,415 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,421 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,426 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,432 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,438 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,443 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,449 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,454 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,460 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,465 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,471 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,476 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,482 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,487 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,493 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,501 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,507 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,512 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,519 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,525 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,530 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,536 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,542 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,547 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,553 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,558 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,563 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,569 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,575 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,580 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,586 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,593 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,598 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,604 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,609 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,615 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,621 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,626 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,631 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,638 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,643 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,649 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,655 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,661 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,667 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,673 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,678 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,684 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,690 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,695 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,701 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,706 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,711 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,718 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,723 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,728 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,734 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,739 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,744 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,749 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,755 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,761 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,767 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,773 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,777 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,783 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,789 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,802 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,814 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,825 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,833 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,840 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,846 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,854 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,861 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,868 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,875 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,881 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,888 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,894 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,900 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,906 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,912 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,917 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,924 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,929 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,935 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,941 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,946 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,952 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,958 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,964 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,970 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,976 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,982 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,988 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,993 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:39,998 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,004 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,010 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,015 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,021 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,026 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,031 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,038 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,043 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,048 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,053 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,059 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,064 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,070 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,076 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,082 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,088 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,093 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,098 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,105 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,110 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,115 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,121 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,126 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,132 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,137 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,143 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,147 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,154 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,159 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,164 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,170 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,175 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,181 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,186 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,192 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,197 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,203 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,209 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,214 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,220 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,226 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,231 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,237 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,242 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,247 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,254 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,259 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,264 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,269 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,275 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,281 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,292 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,297 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,305 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,312 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,318 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,325 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,331 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,339 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,345 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,351 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,357 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,363 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,370 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,376 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,400 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,412 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,419 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,425 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,432 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,438 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,444 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,450 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,457 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,462 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,469 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,475 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,481 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,487 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,493 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,498 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,505 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,511 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,516 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,522 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,528 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,534 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,540 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,545 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,551 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,557 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,563 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,590 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,613 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,620 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,633 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,640 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,646 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,654 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,660 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,667 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,673 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,679 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,686 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,692 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,697 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,703 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,709 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,714 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,720 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,726 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,731 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,737 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,743 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,748 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,755 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,760 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,766 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,772 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,777 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,782 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,788 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,793 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,798 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,804 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,810 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,815 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-06-18 13:03:40,816 - --> Sending MRD_MESSAGE_CLOSE (4)
# 2026-06-18 13:04:37,809 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,812 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,813 - Incoming data will be saved to: 'data/recon.mrd' in group '2026-06-18 13:03:38.369658'
# 2026-06-18 13:04:37,829 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,830 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,838 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,839 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,848 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,849 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,856 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,858 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,867 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,868 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,875 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,876 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,886 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,888 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,895 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,896 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,906 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,907 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,925 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,927 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,934 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,935 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,944 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,945 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,952 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,954 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,962 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,963 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,971 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,972 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,985 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,986 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:37,993 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:37,994 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,003 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,004 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,034 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,035 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,042 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,043 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,049 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,050 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,058 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,059 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,067 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,068 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,075 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,076 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,083 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,084 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,092 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,093 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,102 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,103 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,121 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,122 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,130 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,131 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,139 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,140 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,147 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,148 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,156 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,157 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,165 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,166 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,175 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,176 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,184 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,185 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,199 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,200 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,223 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,224 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,233 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,234 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,243 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,244 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,252 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,253 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,261 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,262 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,269 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,270 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,278 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,279 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,286 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,287 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,296 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,297 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,314 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,316 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,323 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,324 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,331 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,332 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,339 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,340 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,347 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,348 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,355 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,356 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,363 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,365 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,371 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,372 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,380 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,382 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,399 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,400 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,406 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,408 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,415 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,416 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,425 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,426 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,434 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,436 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,444 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,445 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,452 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,453 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,462 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,463 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,470 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,471 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,493 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,494 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,503 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,504 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,513 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,514 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,523 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,524 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,532 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,533 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,541 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,543 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,550 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,551 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,559 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,560 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,568 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,569 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,589 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,590 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,596 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,597 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,608 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,609 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,617 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,618 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,627 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,628 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,636 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,637 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,646 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,647 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,654 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,655 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,664 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,665 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,684 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,686 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,694 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,695 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,706 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,707 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,714 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,715 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,723 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,724 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,731 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,732 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,742 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,743 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,750 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,751 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,761 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,762 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,780 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,782 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,789 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,790 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,798 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,799 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,806 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,807 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,816 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,817 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,824 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,825 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,834 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,836 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,843 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,844 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,852 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,853 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,872 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,873 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,880 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,881 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,891 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,892 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,899 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,899 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,908 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,909 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,916 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,917 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,924 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,926 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,932 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,933 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,942 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,943 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,962 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,964 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,971 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,973 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,982 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,983 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:38,991 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:38,992 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,000 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,001 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,008 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,009 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,020 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,021 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,028 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,029 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,037 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,039 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,058 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,059 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,066 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,067 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,076 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,077 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,083 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,084 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,095 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,096 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,103 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,104 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,113 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,114 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,121 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,122 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,131 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,132 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,157 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,158 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,165 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,166 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,174 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,176 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,182 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,183 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,191 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,192 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,199 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,200 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,207 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,208 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,215 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,215 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,222 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,224 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,241 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,242 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,248 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,249 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,255 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,256 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,262 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,263 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,271 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,273 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,279 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,280 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,287 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,288 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,294 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,295 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,303 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,304 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,322 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,323 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,330 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,331 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,339 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,340 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,347 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,347 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,355 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# ...
# 2026-06-18 13:04:39,749 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,750 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,758 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,759 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,778 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,779 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,787 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,788 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,796 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,797 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,805 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,806 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,815 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,816 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,823 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,824 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,834 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,835 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,843 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,844 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,852 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,853 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,875 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,876 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,885 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,886 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,897 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,899 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,909 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,911 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,922 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,924 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,936 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,937 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,946 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,948 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,957 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,959 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,969 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,970 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:39,993 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:39,994 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,003 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,004 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,013 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,014 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,025 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,026 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,034 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,035 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,045 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,047 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,055 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,057 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,065 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,067 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,076 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,077 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,100 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,102 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,111 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,112 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,121 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,123 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,133 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,134 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,142 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,144 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,152 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,153 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,161 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,162 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,170 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,172 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,182 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,183 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,206 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,208 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,216 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,217 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,228 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,229 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,238 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,239 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,249 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,250 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,261 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,262 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,271 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,273 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,284 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,285 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,295 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,296 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,319 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,320 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,330 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,331 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,340 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,341 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,348 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,350 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,357 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,358 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,366 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,367 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,374 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,375 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,382 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,383 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,392 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,393 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,412 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,413 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,420 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,421 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,429 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,430 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,439 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,440 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,449 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,450 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,459 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,460 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,468 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,469 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,478 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,479 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,487 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,488 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,517 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,518 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,527 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,529 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,539 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,540 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,548 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,549 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,557 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,558 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,566 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,567 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,575 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,576 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,582 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,583 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,592 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,593 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,610 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,612 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,618 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,619 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,626 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,628 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,635 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,636 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,643 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,644 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,653 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,654 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,663 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,664 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,671 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,672 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,679 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,680 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,716 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,718 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,728 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,729 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,738 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,740 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,748 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,749 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,758 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,759 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,766 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,767 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,774 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,776 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,784 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,786 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,796 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,797 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,817 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,818 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,826 - <-- Received MRD_MESSAGE_ISMRMRD_IMAGE (1022)
# 2026-06-18 13:04:40,827 -     Image is size 336 x 256 x 1 with 1 channels of type uint16
# 2026-06-18 13:04:40,834 - <-- Received MRD_MESSAGE_CLOSE (4)
# 2026-06-18 13:04:40,835 -     Total received acquisitions:     0
# 2026-06-18 13:04:40,836 -     Total received images:         282
# 2026-06-18 13:04:40,837 -     Total received waveforms:        0
# 2026-06-18 13:04:40,837 - ------------------------------------------
# 2026-06-18 13:04:40,845 - Socket closed (writer)
# 2026-06-18 13:04:40,853 - ---------------------- Summary ----------------------
# 2026-06-18 13:04:40,853 - Sent     0 acquisitions  |  Received     0 acquisitions
# 2026-06-18 13:04:40,854 - Sent   280 images        |  Received   282 images
# 2026-06-18 13:04:40,854 - Sent     0 waveforms     |  Received     0 waveforms
# 2026-06-18 13:04:40,854 - Results written to data/recon.mrd
# 2026-06-18 13:04:40,855 - Session complete

# %% [markdown]
# # Display the reconstructed/processed images
# The output is an [HDF5-formatted file](https://www.hdfgroup.org/downloads/hdfview/) that is organized in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html).  It can be opened using MRD toolboxes for [python](https://github.com/ismrmrd/ismrmrd-python) or [MATLAB](https://github.com/ismrmrd/ismrmrd/tree/master/matlab/%2Bismrmrd) or the [ismrmrdviewer](https://github.com/ismrmrd/ismrmrdviewer).  The client can be run multiple times with the same output file and results are grouped by dataset.

# %%
# Display the reconstructed images
import h5py
import ismrmrd
import mrdhelper
import numpy as np
import matplotlib.pyplot as plt
import re

# Uncomment to display images from a different output file
outputFilename = 'data/recon.mrd'

# If run multiple times, the recon.mrd file will have multiple reconstructed images
# Find the most recent recon run
with h5py.File(outputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File %s contains %d groups (reconstruction runs):' % (outputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[-1]

with ismrmrd.Dataset(outputFilename, group, False) as dset:
    subgroups = dset.list()

    # Images are organized by series number in subgroups that start with 'image_' or 'images_'
    imgGroups = [group for group in list(subgroups) if (group.find('image_') != -1) or (group.find('images_') != -1)]
    imgGroupsWithNumImages = [f'{group} ({dset.number_of_images(group)} image{"s"[:dset.number_of_images(group)^1]})' for group in imgGroups]
    print('Group %s contains %d image series:' % (group, len(imgGroups)))
    print(' ', '\n  '.join(imgGroupsWithNumImages))

    # Show images
    fig, axs = plt.subplots(nrows=1, ncols=len(imgGroups), squeeze=False, figsize=(10,5))

    for i, series in enumerate(imgGroups):
        n = dset.number_of_images(series)
        img = dset.read_image(series, 0)
        meta = ismrmrd.Meta.deserialize(img.attribute_string)

        seriesNumber = re.search(r'(?<=_)\d+$', series).group(0)
        title = f'Series {re.search(r'(?<=_)\d+$', series).group(0)}, Image 1/{n}'
        if 'ImageComments' in meta.keys():
            title += '\n' + meta['ImageComments']

        axs[0][i].imshow(np.squeeze(img.data), cmap='gray')
        axs[0][i].set_title(title)
        axs[0][i].axis('off')
        axs[0][i].set_aspect('equal')

        # Read and plot ROIs
        for key in meta.keys():
            if not key.startswith('ROI_'):
                continue

            roi = meta[key]
            x, y, rgb, thickness, style, visibility = mrdhelper.parse_roi(roi)

            if visibility == 0:
                continue

            lstyle = '-' if (style == 0) else '--'
            axs[0][i].plot(x, y, color=rgb, linewidth=thickness, linestyle=lstyle)
        
        maxKeyLen = max([len(key) for key in meta.keys()])
        print("MetaAttributes:")
        for key, value in meta.items():
            print(f'  {key:{maxKeyLen}} : {value}')

    # Adjust layout to prevent clipping of titles
    plt.tight_layout(pad=0.5)

    plt.show()
# Out:
# File data/recon.mrd contains 20 groups (reconstruction runs):
#   2026-06-01 09:33:32.828918
#   2026-06-01 10:00:22.787041
#   2026-06-01 10:00:42.952301
#   2026-06-01 10:42:58.577762
#   2026-06-01 10:45:18.122040
#   2026-06-01 10:47:37.430498
#   2026-06-01 10:48:20.326888
#   2026-06-01 10:55:01.929994
#   2026-06-01 10:55:23.106971
#   2026-06-01 11:01:59.343331
#   2026-06-01 11:02:22.481313
#   2026-06-01 11:08:12.967541
#   2026-06-03 08:47:51.276796
#   2026-06-10 12:04:34.153889
#   2026-06-10 13:30:28.642786
#   2026-06-18 11:29:37.325057
#   2026-06-18 11:30:57.045951
#   2026-06-18 11:32:07.217002
#   2026-06-18 12:57:21.223093
#   2026-06-18 13:03:38.369658
# Group 2026-06-18 13:03:38.369658 contains 2 image series:
#   image_0 (2 images)
#   image_99 (280 images)
# MetaAttributes:
#   ImageType                     : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription           : trufi_lung
#   DicomJson                     : ...
#   DataRole                      : Image
#   ImageProcessingHistory        : ['PYTHON', 'INVERT']
#   WindowCenter                  : 2048.0
#   WindowWidth                   : 4096
#   SequenceDescriptionAdditional : FIRE
#   Keep_image_geometry           : 1
#   ImageRowDir                   : ['1.000000000000000000', '0.000000000000000000', '0.000000000000000000']
#   ImageColumnDir                : ['0.000000000000000000', '0.000000000000000000', '-1.000000000000000000']
# MetaAttributes:
#   ImageType           : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription : trufi_lung
#   DicomJson           : ...
#   Keep_image_geometry : 1
# /usr/local/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
