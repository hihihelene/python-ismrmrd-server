# %% [markdown]
# # Create/convert an input dataset in MRD format
#
# Prepare a dataset in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html) by converting acquired data or by generating a synthetic phantom dataset.  Raw k-space data can be converted using tools such as [siemens_to_ismrmrd](https://github.com/ismrmrd/siemens_to_ismrmrd), [ge_to_ismrmrd](https://github.com/ismrmrd/ge_to_ismrmrd), [philips_to_ismrmrd](https://github.com/ismrmrd/philips_to_ismrmrd), and [bruker_to_ismrmrd](https://github.com/ismrmrd/bruker_to_ismrmrd), while DICOM image data can be converted to DICOM using [dicom2mrd.py](https://github.com/kspaceKelvin/python-ismrmrd-server#UsingDICOMimagesasinputdata).  The [generate_cartesian_shepp_logan_dataset.py](../generate_cartesian_shepp_logan_dataset.py) script can also be used to generate multi-channel raw k-space data.

# %% [markdown]
# ## Option 1: Simulate a raw k-space dataset of the Shepp-Logan phantom
# **Note** This section requires that the [ismrmrd-python-tools](https://github.com/ismrmrd/ismrmrd-python-tools) repo be installed (see [readme.md](../readme.md#Settingupacondaenvironment))

# %%
# Generate a raw k-space dataset of the Shepp-Logan phantom
import os
import generate_cartesian_shepp_logan_dataset

inputFilename = 'data/raw.mrd'

dir, file = os.path.split(inputFilename)
if dir and not os.path.exists(dir):
    print(f'Creating parent directory {dir}')
    os.makedirs(dir)

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

generate_cartesian_shepp_logan_dataset.create(filename=inputFilename, matrix_size=256, coils=8, oversampling=2, repetitions=1, acceleration=1, noise_level=0.05)
# Out:
# Creating Shepp-Logan phantom raw data:
# Matrix 256x256 at R=1 with 1 repetitions
# 8 coils with 2 oversampling and 0.05 noise level
# Saved to data/raw.mrd

# %% [markdown]
# ## Option 2: Convert raw k-space data acquired from an MRI scanner

# %%
# Run siemens_to_ismrmrd to convert a .dat file into MRD format
# Note that as there is no Windows executable, this must be run in Linux or in a devcontainer

# Relative path to Siemens .dat file (note this .ipynb file likely exists in the doc subfolder!)
datFile = 'data/MiniFLASH_Fire.dat'

# Measurement in the multi-RAID .dat file to convert.  Note the .dat file may contain dependent
# scans, e.g. AdjCoilSens and the desired scan is usually the last in the multi-RAID file
# Negative indices are relative to the end (e.g. -1 for the last measurement)
measNum = '-1'

# Parameter map and stylesheet to use to convert from Siemens parameter buffers to an MRD header.
# These can specify a relative path to local files or files embedded inside siemens_to_ismrmrd.
# These arguments can also be omitted and will default to these values.
paramMap      = None
paramMapStyle = None

# The output file can be specified with the "--output" option, but will be named with the same
# filename as the input file (with a .mrd extension) if omitted.

import subprocess
import os

inputFilename = os.path.splitext(datFile)[0] + '.mrd'
if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

command = ['siemens_to_ismrmrd', '--measNum', measNum, '--file', datFile]
if paramMap is not None:
    command.extend(('--pMap', paramMap))

if paramMapStyle is not None:
    command.extend(('--pMapStyle', paramMapStyle))

try:
    result = subprocess.run(command, check=True, text=True, capture_output=True)
    print("Output:", result.stdout)
except subprocess.CalledProcessError as e:
    raise Exception("Error:", e.stderr)
# Out:
# Output: Siemens file is: data/MiniFLASH_Fire.dat
# Output file not specified -- using data/MiniFLASH_Fire.mrd
# -----------------------------------------------------------------
# Converting measurement 1 into file data/MiniFLASH_Fire.mrd in group dataset
# -----------------------------------------------------------------
# Using parameter map: IsmrmrdParameterMap_Siemens.xml
# This file contains 1 measurement(s).
# VD line file detected.
# Protocol name [1]: MiniFLASH_Fire
# Number of parameter buffers: 6
# Buffer Name: Config
# Buffer Name: Dicom
# Buffer Name: Meas
# Buffer Name: MeasYaps
# Buffer Name: Phoenix
# Buffer Name: Spice
# Trajectory is: 1
# Failed to find YAPS.lFirstFourierLine array
# Failed to find YAPS.lFirstFourierPartition array
# center_line = 64
# center_partition = 0
# Baseline: N4_VE11C_LATEST_20160120
# Software version: syngo MR E11
# Protocol name: MiniFLASH_Fire
# Dwell time: 15000
# Using parameter XSL: IsmrmrdParameterMap_Siemens.xsl
# Study time: 16:06:09
# Last scan reached...

# %% [markdown]
# ## Visualize raw k-space data
# Inspect and visualize the raw k-space dataset using the [ismrmrd-python](https://github.com/ismrmrd/ismrmrd-python) library.  Data from multiple scans/acquisitions can be stored in a single file, grouped in ['datasets'](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html#mrd-file-format).  The datasets in a file can be listed with:

# %%
# Display the generated raw k-space data
import h5py
import ismrmrd
import numpy as np
import matplotlib.pyplot as plt

datasetName = 'dataset'

# List all datasets in the file
with h5py.File(inputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File "%s" contains %d datasets:' % (inputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[0]

    datasetName = list(d.keys())[0]

print('Reading dataset "%s" from file "%s"' % (datasetName, inputFilename))
with ismrmrd.Dataset(inputFilename, datasetName, False) as dset:
    # Read MRD header
    xmlHeader = dset.read_xml_header().decode('utf-8')
    mrdHeader = ismrmrd.xsd.CreateFromDocument(xmlHeader)

    # Get all readouts
    acqs = [dset.read_acquisition(idx) for idx in range(dset.number_of_acquisitions())]

    # Limit to imaging (non-noise) readouts
    imgAcqs = [acq for acq in acqs if not acq.is_flag_set(ismrmrd.ACQ_IS_NOISE_MEASUREMENT)]

    print('There are %d imaging readouts out of a total of %d readouts' % (len(imgAcqs), dset.number_of_acquisitions()))

# List index counters that have >1 unique values
idxFields = ['average', 'contrast', 'kspace_encode_step_1', 'kspace_encode_step_2', 'phase', 'repetition', 'segment', 'set', 'slice']
print("Loop index counters with unique values:")
for field in idxFields:
    vals = set([getattr(acq.idx, field) for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  {field:20s} has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

for i in range(8):
    vals = set([acq.idx.user[i] for acq in imgAcqs])
    if len(vals) > 1:
        print(f'  user[{i}]              has {len(vals):3d} unique values (min: {min(vals):3d}, max: {max(vals):3d})')

# Format data into single [cha PE RO rep] array
lin = [acq.idx.kspace_encode_step_1 for acq in imgAcqs]
rep = [acq.idx.repetition           for acq in imgAcqs]

raw = np.zeros((mrdHeader.acquisitionSystemInformation.receiverChannels, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.y, 
                mrdHeader.encoding[0].encodedSpace.matrixSize.x, 
                mrdHeader.encoding[0].encodingLimits.repetition.maximum+1), 
                imgAcqs[0].data.dtype)

for acq, lin, rep in zip(imgAcqs, lin, rep):
    raw[:,lin,-acq.data.shape[1]:,rep] = acq.data

# Show the AcquisitionHeader flags for each line of k-space
print("Readouts with AcquisitionHeader flags present:")
acqFlags = [field for field in dir(ismrmrd) if field.startswith('ACQ_')]
for i, acq in enumerate(imgAcqs):
    strFlags = ", ".join([field for field in acqFlags if acq.is_flag_set(getattr(ismrmrd, field))])
    if strFlags:
        print(f'[{i:3d}] Lin {acq.idx.kspace_encode_step_1}: {strFlags}')

t = np.log(np.abs(raw[0,:,:,0]))
t[np.isinf(t)] = 0

dpi = 100
plt.figure(figsize=(3*t.shape[1] / dpi, 3*t.shape[0] / dpi), dpi=dpi)
plt.imshow(t, interpolation='nearest')
plt.title('Raw k-space (rep %d/%d, coil %d/%d)' % (1, mrdHeader.encoding[0].encodingLimits.repetition.maximum+1, 1, mrdHeader.acquisitionSystemInformation.receiverChannels))
# plt.axis('off')
plt.show()
# Out:
# File "data/MiniFLASH_Fire.mrd" contains 1 datasets:
#   dataset
# Reading dataset "dataset" from file "data/MiniFLASH_Fire.mrd"
# There are 128 imaging readouts out of a total of 128 readouts
# Loop index counters with unique values:
#   kspace_encode_step_1 has 128 unique values (min:   0, max: 127)
# Readouts with AcquisitionHeader flags present:
# [  0] Lin 0: ACQ_FIRST_IN_SLICE
# [127] Lin 127: ACQ_LAST_IN_MEASUREMENT, ACQ_LAST_IN_REPETITION, ACQ_LAST_IN_SLICE

# %% [markdown]
# ## Option 3: Convert a set of DICOMs
# For image processing workflows, it may also be useful to use DICOM images as input data.  These can be converted to MRD format using the [dicom2mrd.py](../dicom2mrd.py) script.  Not that the header information from data converted in this way may differ from data converted from the scanner.

# %%
# Folder containing DICOM files
import os
dicomFolder   = r'C:/Lung_Project/Measurements/CDH_Study/20260217_age10'
inputFilename = 'data/dicoms.mrd'

if os.path.exists(inputFilename):
    overwrite = input(f'File {inputFilename} already exists!  Overwrite? y/[n]')
    if overwrite.lower() == 'y':
        os.remove(inputFilename)
    else:
        raise Exception('Aborting to not overwrite existing file')

import dicom2mrd
from types import SimpleNamespace

# Adjust the logging configuration otherwise INFO level isn't shown in notebook output
import logging
logging.getLogger().setLevel(logging.INFO)

# Specify client arguments for recon
args = SimpleNamespace(**dicom2mrd.defaults)
args.folder   = dicomFolder
args.outFile  = inputFilename

dicom2mrd.main(args)
# Out:
# Found 1 unique series from 280 files in folder C:/Lung_Project/Measurements/CDH_Study/20260217_age10
# Creating MRD XML header from file C:/Lung_Project/Measurements/CDH_Study/20260217_age10\1.dcm
# <?xml version="1.0" encoding="ascii"?>
# <ismrmrdHeader xmlns="http://www.ismrm.org/ISMRMRD">
#  <studyInformation>
#   <studyDate>2026-02-17</studyDate>
#   <studyTime>10:35:55</studyTime>
#   <studyID>05046715</studyID>
#   <studyDescription>Kinderprotokolle Untersuchung_neu</studyDescription>
#   <studyInstanceUID>1.3.12.2.1107.5.2.18.141978.30000026030214074498000000297</studyInstanceUID>
#   <bodyPartExamined>CHEST</bodyPartExamined>
#  </studyInformation>
#  <measurementInformation>
#   <measurementID>1.3.12.2.1107.5.2.18.141978.30000026030214074498000000305</measurementID>
#   <patientPosition>HFS</patientPosition>
#   <protocolName>trufi_lung</protocolName>
#   <frameOfReferenceUID>1.3.12.2.1107.5.2.18.141978.30000026030214074498000000306</frameOfReferenceUID>
#  </measurementInformation>
#  <acquisitionSystemInformation>
#   <systemVendor>Siemens Healthineers</systemVendor>
#   <systemModel>MAGNETOM Aera</systemModel>
#   <systemFieldStrength_T>1.5</systemFieldStrength_T>
#  </acquisitionSystemInformation>
#  <experimentalConditions>
#   <H1resonanceFrequency_Hz>63870000</H1resonanceFrequency_Hz>
#  </experimentalConditions>
#  <encoding>
#   <encodedSpace>
#    <matrixSize>
#     <x>336</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </encodedSpace>
#   <reconSpace>
#    <matrixSize>
#     <x>336</x>
#     <y>256</y>
#     <z>1</z>
#    </matrixSize>
#   </reconSpace>
#   <encodingLimits/>
#   <trajectory>cartesian</trajectory>
#   <parallelImaging>
#    <accelerationFactor>
#     <kspace_encoding_step_1>3</kspace_encoding_step_1>
#     <kspace_encoding_step_2>1</kspace_encoding_step_2>
#    </accelerationFactor>
#   </parallelImaging>
#  </encoding>
#  <sequenceParameters>
#   <TR>2.18</TR>
#   <flipAngle_deg>30.0</flipAngle_deg>
#  </sequenceParameters>
#  <userParameters>
#   <userParameterDouble>
#    <name>ReadoutOS</name>
#    <value>2.0</value>
#   </userParameterDouble>
#  </userParameters>
# </ismrmrdHeader>
#
# Series 19 has 280 images with 1 slices and 1 phases
# Creating MRD file data/dicoms.mrd with group dataset

# %% [markdown]
# ## Option 4: Save data using server.py
# For inline integration with an MRI scanner or another data source, the conversion to MRD may be done with vendor-provided software.  In this case, it may be desirable to use MRD server in this repository to save a copy of data that it receives, particularly for development purposes.  The data can then be re-run with [client.py](../client.py).  This can be achieved by starting the server with [main.py](../main.py) with the `-s` (`--savedata`) option and data is stored in `/tmp/share/saved_data` unless overridden by the `-S` (`--savedataFolder`) option.

# %%
inputFilename = 'data/dicoms.mrd'

# %% [markdown]
# # Run reconstruction
# Algorithms/reconstructions are run as modules by the server component, which implements the [MRD streaming protocol](https://ismrmrd.readthedocs.io/en/latest/mrd_streaming_protocol.html).  The server must be started separately and a client sends data to the server for processing.  The server can be started via command line by running `python main.py`.
#
# If using Visual Studio Code, [launch.json](../.vscode/launch.json) includes a debug configuration to run the server and allow for interactive debugging.  Click on the "Run and Debug" tab on the top left, then click the green play button to start the desired config ("Start server"):
#
# ![image-2.png](attachment:image-2.png)
#
# Breakpoints can be set by clicking to the left of the line number in a Python file:
#
# ![image.png](attachment:image.png)
#
# After the server is started, begin the reconstruction by running [client.py](../client.py) on the input dataset.  The recon code/module is selected by using the `config` argument.  The output is stored in a separate MRD file under a dataset named with the current date/time.

# %%
# Import the MRD client to send data to server for reconstruction
import client
from types import SimpleNamespace

# Adjust the logging configuration, otherwise INFO level isn't shown in notebook output by default
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

import datetime
outputFilename = 'data/recon.mrd'

# Specify client arguments for recon
args = SimpleNamespace(**client.defaults)
args.config    = 'custom.MAIN_VQMap'  # Recon module to be used
args.port      = 9020
args.out_group = str(datetime.datetime.now())  # Set when using in notebook, otherwise out_group is time of first import of client module
args.outfile   = outputFilename
args.filename  = inputFilename

client.main(args)
# Out:
# 2026-07-07 08:45:14,277 - Found additional config file custom.MAIN_VQMap.json
# 2026-07-07 08:45:14,281 - File data/dicoms.mrd contains 1 groups:
# 2026-07-07 08:45:14,281 - dataset
# 2026-07-07 08:45:14,282 - Reading data from group 'dataset' in file 'data/dicoms.mrd'
# 2026-07-07 08:45:14,283 - Connecting to MRD server at localhost:9020
# No logfile provided
# 2026-07-07 08:45:14,287 - Sending remote config file name 'custom.MAIN_VQMap'
# 2026-07-07 08:45:14,291 - --> Sending MRD_MESSAGE_CONFIG_FILE (1)
# 2026-07-07 08:45:14,301 - --> Sending MRD_MESSAGE_METADATA_XML_TEXT (3)
# 2026-07-07 08:45:14,301 - Sending configAdditional found in file custom.MAIN_VQMap.json:
# {
#     "version": "1.1.0",
#     "parameters": {
#         "options": "RGB",
#         "sendOriginal": "True",
#         "segmentationmethod": "nnunet",
#         "spectralanalysis": "FD",
#         "phantom": true,
#         "skipfirst": 8
#     }
# }
# 2026-07-07 08:45:14,302 - --> Sending MRD_MESSAGE_TEXT (5)
# 2026-07-07 08:45:14,303 -     {
#     "version": "1.1.0",
#     "parameters": {
#         "options": "RGB",
#         "sendOriginal": "True",
#         "segmentationmethod": "nnunet",
#         "spectralanalysis": "FD",
#         "phantom": true,
#         "skipfirst": 8
#     }
# }
# 2026-07-07 08:45:14,304 - Starting image data session
# 2026-07-07 08:45:14,304 - Reading images from '/dataset/image_0'
# 2026-07-07 08:45:14,321 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,329 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,337 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,344 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,350 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,358 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,363 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,979 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,985 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,990 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:14,997 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,005 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,010 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,028 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,034 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,039 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,044 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,050 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,055 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,060 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,065 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,071 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,077 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,083 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,089 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,094 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,101 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,106 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,112 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,117 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,123 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,129 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,134 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,140 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,145 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,151 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,157 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,161 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,168 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,173 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,178 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,185 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,191 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,196 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,203 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,208 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,216 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,222 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,228 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,234 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,240 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,245 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,252 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,258 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,263 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,271 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,276 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,282 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,288 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,293 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,300 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,307 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,313 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,320 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,326 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,332 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,339 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,345 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,353 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,358 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,364 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,371 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,377 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,383 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,390 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,395 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,402 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,408 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,415 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,421 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,428 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,434 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,440 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,446 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,452 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,458 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,465 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,471 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,476 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,483 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,489 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,495 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,501 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,507 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,513 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,519 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,525 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,530 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,536 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,542 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,548 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,555 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,560 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,566 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,577 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,585 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,590 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,596 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,603 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,609 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,615 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,621 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,627 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,633 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,639 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,644 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,651 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,657 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,663 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,669 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,675 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,680 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,687 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,693 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,698 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,704 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,709 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,715 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,721 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,726 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,731 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,737 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,742 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,748 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,753 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,759 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,764 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,770 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,775 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,780 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,787 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,792 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,798 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,804 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,809 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,815 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,820 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,827 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,832 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,839 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,847 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,854 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,859 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,866 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,872 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,877 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,883 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,888 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,894 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,899 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,905 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,912 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,918 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,924 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,929 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,936 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,942 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,947 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,953 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,959 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,964 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,970 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,975 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,981 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,987 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,992 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:15,998 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,003 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,009 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,014 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,020 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,026 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,031 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,037 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,042 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,047 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,053 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,058 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,063 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,069 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,073 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,078 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,084 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,089 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,095 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,102 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,107 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,112 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,118 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,123 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,129 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,134 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,140 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,145 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,151 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,156 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,161 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,169 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,175 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,179 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,186 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,191 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,196 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,203 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,209 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,215 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,220 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,225 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,230 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,237 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,242 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,247 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,253 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,258 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,263 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,268 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,274 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,278 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,285 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,290 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,295 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,303 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,308 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,313 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,320 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,325 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,330 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,336 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,342 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,348 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,355 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,361 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,368 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,373 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,379 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,386 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,394 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,402 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,409 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,416 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,423 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,428 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,436 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,442 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,447 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,453 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,459 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,464 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,471 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,476 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,482 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,488 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,493 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,499 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,505 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,510 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,516 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,522 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,527 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,533 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,539 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,544 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,551 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,561 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,567 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,573 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,579 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,587 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,593 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,599 - --> Sending MRD_MESSAGE_ISMRMRD_IMAGE (1022) (1 images)
# 2026-07-07 08:45:16,601 - --> Sending MRD_MESSAGE_CLOSE (4)
# 2026-07-07 08:46:10,661 - <-- Received MRD_MESSAGE_TEXT (5)
# 2026-07-07 08:46:10,662 -     ERROR    Traceback (most recent call last):
#   File "/workspaces/python-ismrmrd-server/custom/MAIN_VQMap.py", line 159, in process
#     image = process_image(imgGroup, connection, config, mrdHeader)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspaces/python-ismrmrd-server/custom/MAIN_VQMap.py", line 360, in process_image
#     VQMaps = VQMapping_online(data, head, None, PipelineConfig)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspaces/python-ismrmrd-server/custom/VQMapping.py", line 403, in VQMapping_online
#     QMap = result.perf_map / np.percentile(result.perf_map[result.lung_mask], p*100)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/numpy/lib/function_base.py", line 4283, in percentile
#     return _quantile_unchecked(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/numpy/lib/function_base.py", line 4555, in _quantile_unchecked
#     return _ureduce(a,
#            ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/numpy/lib/function_base.py", line 3823, in _ureduce
#     r = func(a, **kwargs)
#         ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/numpy/lib/function_base.py", line 4722, in _quantile_ureduce_func
#     result = _quantile(arr,
#              ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/numpy/lib/function_base.py", line 4824, in _quantile
#     arr.partition(
# TypeError: '<' not supported between instances of 'NoneType' and 'NoneType'
#
# 2026-07-07 08:46:10,663 - <-- Received MRD_MESSAGE_CLOSE (4)
# 2026-07-07 08:46:10,664 -     Total received acquisitions:     0
# 2026-07-07 08:46:10,665 -     Total received images:           0
# 2026-07-07 08:46:10,665 -     Total received waveforms:        0
# 2026-07-07 08:46:10,666 - ------------------------------------------
# 2026-07-07 08:46:10,666 - Incoming data will be saved to: 'data/recon.mrd' in group '2026-07-07 08:45:14.276525'
# 2026-07-07 08:46:10,675 - Socket closed (writer)
# 2026-07-07 08:46:10,686 - ---------------------- Summary ----------------------
# 2026-07-07 08:46:10,687 - Sent     0 acquisitions  |  Received     0 acquisitions
# 2026-07-07 08:46:10,687 - Sent   280 images        |  Received     0 images
# 2026-07-07 08:46:10,688 - Sent     0 waveforms     |  Received     0 waveforms
# 2026-07-07 08:46:10,688 - Results written to data/recon.mrd
# 2026-07-07 08:46:10,689 - Session complete

# %% [markdown]
# # Display the reconstructed/processed images
# The output is an [HDF5-formatted file](https://www.hdfgroup.org/downloads/hdfview/) that is organized in the [MRD file format](https://ismrmrd.readthedocs.io/en/latest/mrd_files.html).  It can be opened using MRD toolboxes for [python](https://github.com/ismrmrd/ismrmrd-python) or [MATLAB](https://github.com/ismrmrd/ismrmrd/tree/master/matlab/%2Bismrmrd) or the [ismrmrdviewer](https://github.com/ismrmrd/ismrmrdviewer).  The client can be run multiple times with the same output file and results are grouped by dataset.

# %%
# Display the reconstructed images
import h5py
import ismrmrd
import mrdhelper
import numpy as np
import matplotlib.pyplot as plt
import re

# Uncomment to display images from a different output file
outputFilename = 'data/recon.mrd'

# If run multiple times, the recon.mrd file will have multiple reconstructed images
# Find the most recent recon run
with h5py.File(outputFilename, 'r') as d:
    dsetNames = d.keys()
    print('File %s contains %d groups (reconstruction runs):' % (outputFilename, len(dsetNames)))
    print(' ', '\n  '.join(dsetNames))
    group = list(dsetNames)[-1]

with ismrmrd.Dataset(outputFilename, group, False) as dset:
    subgroups = dset.list()

    # Images are organized by series number in subgroups that start with 'image_' or 'images_'
    imgGroups = [group for group in list(subgroups) if (group.find('image_') != -1) or (group.find('images_') != -1)]
    imgGroupsWithNumImages = [f'{group} ({dset.number_of_images(group)} image{"s"[:dset.number_of_images(group)^1]})' for group in imgGroups]
    print('Group %s contains %d image series:' % (group, len(imgGroups)))
    print(' ', '\n  '.join(imgGroupsWithNumImages))

    # Show images
    fig, axs = plt.subplots(nrows=1, ncols=len(imgGroups), squeeze=False, figsize=(10,5))

    for i, series in enumerate(imgGroups):
        n = dset.number_of_images(series)
        img = dset.read_image(series, 0)
        meta = ismrmrd.Meta.deserialize(img.attribute_string)

        seriesNumber = re.search(r'(?<=_)\d+$', series).group(0)
        title = f'Series {re.search(r'(?<=_)\d+$', series).group(0)}, Image 1/{n}'
        if 'ImageComments' in meta.keys():
            title += '\n' + meta['ImageComments']

        axs[0][i].imshow(np.squeeze(img.data), cmap='gray')
        axs[0][i].set_title(title)
        axs[0][i].axis('off')
        axs[0][i].set_aspect('equal')

        # Read and plot ROIs
        for key in meta.keys():
            if not key.startswith('ROI_'):
                continue

            roi = meta[key]
            x, y, rgb, thickness, style, visibility = mrdhelper.parse_roi(roi)

            if visibility == 0:
                continue

            lstyle = '-' if (style == 0) else '--'
            axs[0][i].plot(x, y, color=rgb, linewidth=thickness, linestyle=lstyle)
        
        maxKeyLen = max([len(key) for key in meta.keys()])
        print("MetaAttributes:")
        for key, value in meta.items():
            print(f'  {key:{maxKeyLen}} : {value}')

    # Adjust layout to prevent clipping of titles
    plt.tight_layout(pad=0.5)

    plt.show()
# Out:
# File data/recon.mrd contains 64 groups (reconstruction runs):
#   2026-06-01 09:33:32.828918
#   2026-06-01 10:00:22.787041
#   2026-06-01 10:00:42.952301
#   2026-06-01 10:42:58.577762
#   2026-06-01 10:45:18.122040
#   2026-06-01 10:47:37.430498
#   2026-06-01 10:48:20.326888
#   2026-06-01 10:55:01.929994
#   2026-06-01 10:55:23.106971
#   2026-06-01 11:01:59.343331
#   2026-06-01 11:02:22.481313
#   2026-06-01 11:08:12.967541
#   2026-06-03 08:47:51.276796
#   2026-06-10 12:04:34.153889
#   2026-06-10 13:30:28.642786
#   2026-06-18 11:29:37.325057
#   2026-06-18 11:30:57.045951
#   2026-06-18 11:32:07.217002
#   2026-06-18 12:57:21.223093
#   2026-06-18 13:03:38.369658
#   2026-06-29 11:48:45.085287
#   2026-06-29 11:49:40.780163
#   2026-06-29 11:50:25.959546
#   2026-06-29 11:51:25.551268
#   2026-06-29 11:52:57.121881
#   2026-06-29 11:54:57.369100
#   2026-06-29 11:57:32.197499
#   2026-06-29 11:59:50.198185
#   2026-06-29 12:09:36.846528
#   2026-06-29 12:10:30.551481
#   2026-06-29 12:13:00.488793
#   2026-06-29 13:32:15.542261
#   2026-07-02 07:24:08.497167
#   2026-07-02 07:26:29.889842
#   2026-07-02 07:35:08.184958
#   2026-07-02 07:40:44.707861
#   2026-07-02 07:43:05.557287
#   2026-07-02 07:57:39.965291
#   2026-07-02 08:00:50.968532
#   2026-07-02 08:28:51.110756
#   2026-07-02 08:37:13.606138
#   2026-07-02 08:37:49.945050
#   2026-07-02 08:44:54.116342
#   2026-07-02 08:46:18.094615
#   2026-07-02 08:48:50.465965
#   2026-07-02 08:49:52.017281
#   2026-07-02 08:59:39.261517
#   2026-07-02 08:59:56.593309
#   2026-07-02 09:29:50.712332
#   2026-07-02 09:35:04.724098
#   2026-07-02 09:37:01.680073
#   2026-07-02 09:39:35.344017
#   2026-07-02 09:42:16.575656
#   2026-07-02 09:43:54.450253
#   2026-07-02 11:35:38.907687
#   2026-07-02 11:36:01.611713
#   2026-07-02 11:36:17.498831
#   2026-07-02 11:37:03.753683
#   2026-07-02 11:38:32.304329
#   2026-07-02 12:10:00.688646
#   2026-07-02 12:11:37.468003
#   2026-07-07 07:46:59.562875
#   2026-07-07 07:47:45.957575
#   2026-07-07 08:33:12.262893
# Group 2026-07-07 08:33:12.262893 contains 2 image series:
#   image_0 (2 images)
#   image_99 (280 images)
# MetaAttributes:
#   ImageType                     : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription           : trufi_lung
#   DicomJson                     : ...
#   DataRole                      : Image
#   ImageProcessingHistory        : ['PYTHON', 'INVERT']
#   WindowCenter                  : 2048.0
#   WindowWidth                   : 4096
#   SequenceDescriptionAdditional : FIRE
#   Keep_image_geometry           : 1
#   ImageRowDir                   : ['1.000000000000000000', '0.000000000000000000', '0.000000000000000000']
#   ImageColumnDir                : ['0.000000000000000000', '0.000000000000000000', '-1.000000000000000000']
# MetaAttributes:
#   ImageType           : ['ORIGINAL', 'PRIMARY', 'M', 'NONE']
#   SequenceDescription : trufi_lung
#   DicomJson           : ...
#   Keep_image_geometry : 1
